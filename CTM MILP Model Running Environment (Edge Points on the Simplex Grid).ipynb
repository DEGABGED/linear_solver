# %% [markdown]
# # CTM MILP Model Running Environment (Edge Points on the Simplex Grid)

# %% [markdown]
# **NOTE:** When about to make a new run, please **duplicate** this notebook then add necessary graphs and things below.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random
from pprint import pprint
import time

from ctmmodels.const import *

# Add more CTM models here as needed
from ctmmodels.ringbarrier import DTSimplexRingBarrier as NewModel
from ctmmodels.parentmodel import ParentModel as OldModel

# %%
IMAGE_PATH = 'graphs/'
DF_PATH = 'dataframes/'

# %% [markdown]
# **Notes on the models and parameters being used:**
#
# * Default parameters used before:
#
# {
#
#     time_range = 30
#     time_ticks = np.arange(0, time_range+1, 1)
#
#     parameters = {
#         'r_left': 1.0/3.0,
#         'r_through': 1.0/3.0,
#         'r_right': 1.0/3.0,
#         'sat_flow_rate': 1800,
#         'time_range': time_range,
#         'time_step': 2,
#         'g_min': 6,
#         'g_max': 20
#     }
#
# }
#
# * Saturation flow rate was set to 1800 vphpl, as this was the closest realistic value that matched the calculations from the parent paper.
#
# * Traffic will be distributed evenly between the 4 lanes (left, through 1, through 2, and right). This is based on previous tests where left was getting essentially 0 green time.
#
# * Time range will be set to 60 seconds, or 30 time steps at 2 seconds per time step.

# %%
time_range = 30
time_ticks = np.arange(0, time_range+1, 1)

parameters = {
    'r_left': 0.25,
    'r_through': 0.5,
    'r_right': 0.25,
    'sat_flow_rate': 1800,
    'time_range': time_range,
    'time_step': 2,
    'g_min': 6,
    'g_max': 20,
    'flow_rate_reduction': 1
}

# Varying parameters: demand, alpha, beta, gamma

# %%
def run_model(demand, weights=(0.33, 0.33, 0.33), new_model=True, log_output=True):
    if new_model:
        model = NewModel(
            demand=demand,
            alpha=weights[0],
            beta=weights[1],
            gamma=weights[2],
            **parameters
        )
    else:
        model = OldModel(
            demand=demand,
            **parameters
        )

    model.generate()
    runtime = model.solve(log_output=log_output)
    return model, runtime

# %%
newmodel, newruntime = run_model(450, new_model=True, weights=(0,1,0))
# Out:
# Solving...
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 2 times.
# MIP Presolve eliminated 3256 rows and 320 columns.
# MIP Presolve modified 740 coefficients.
# Aggregator did 134 substitutions.
# Reduced MIP has 3412 rows, 1886 columns, and 11284 nonzeros.
# Reduced MIP has 270 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.02 sec. (13.06 ticks)
# Found incumbent of value 0.000000 after 0.03 sec. (24.00 ticks)
# Probing fixed 0 vars, tightened 100 bounds.
# Probing time = 0.00 sec. (0.54 ticks)
# Tried aggregator 2 times.
# MIP Presolve eliminated 580 rows and 100 columns.
# Aggregator did 88 substitutions.
# Reduced MIP has 2744 rows, 1698 columns, and 9832 nonzeros.
# Reduced MIP has 270 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (8.03 ticks)
# Probing time = 0.00 sec. (1.17 ticks)
# Clique table members: 540.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 8 threads.
# Root relaxation solution time = 0.20 sec. (230.81 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                            0.0000    -1099.7193              ---
#       0     0     -250.0000   242        0.0000     -250.0000        0     ---
# *     0+    0                         -160.8428     -250.0000            55.43%
#       0     0     -250.0000   222     -160.8428      Cuts: 29       52   55.43%
# *     0+    0                         -183.2860     -250.0000            36.40%
#       0     0     -250.0000   233     -183.2860      Cuts: 92      398   36.40%
# *     0+    0                         -197.4195     -250.0000            26.63%
#       0     0     -250.0000   231     -197.4195       Cuts: 8      426   26.63%
#       0     2     -250.0000   220     -197.4195     -250.0000      426   26.63%
# Elapsed time = 2.29 sec. (1423.56 ticks, tree = 0.01 MB, solutions = 4)
#      24    18     -233.0611   173     -197.4195     -250.0000     4536   26.63%
#     176   123     -226.4086   132     -197.4195     -250.0000    17492   26.63%
#     339   235     -239.0922   167     -197.4195     -250.0000    32256   26.63%
#     533   378     -210.1176   101     -197.4195     -250.0000    44104   26.63%
#     668   486     -225.9066   133     -197.4195     -244.6336    53582   23.92%
#     774   533     -220.0009   137     -197.4195     -242.5887    59070   22.88%
#     929   637     -202.1721    76     -197.4195     -242.5887    65337   22.88%
# *   955+  630                         -199.1832     -242.5887            21.79%
#    1078   710     -213.7338   109     -199.1832     -242.5887    70671   21.79%
#    1262   822        cutoff           -199.1832     -239.0600    80465   20.02%
#    1982  1344     -203.8589   102     -199.1832     -235.3048   121331   18.13%
# Elapsed time = 6.97 sec. (4536.42 ticks, tree = 18.62 MB, solutions = 5)
#    2472  1618        cutoff           -199.1832     -233.7775   139407   17.37%
#    3282  2201     -224.5628   161     -199.1832     -231.8603   188565   16.41%
#    3428  2380     -250.0000   238     -199.1832     -231.7129   207889   16.33%
#    3456   112     -224.9494   163     -199.1832     -231.7129   213054   16.33%
#    4090   471     -221.0312   114     -199.1832     -231.7129   269175   16.33%
#    4521   802     -222.7318   139     -199.1832     -231.7129   325322   16.33%
#    5055  1197     -219.4618   134     -199.1832     -231.7129   398385   16.33%
#    5588  1580     -211.7701   100     -199.1832     -231.7129   469069   16.33%
#    6131  1937     -218.4067   126     -199.1832     -231.6051   539303   16.28%
#    6657  2273     -205.6914    88     -199.1832     -230.5136   597276   15.73%
# Elapsed time = 24.21 sec. (16370.60 ticks, tree = 6.21 MB, solutions = 5)
# *  6744+ 2388                         -200.1184     -230.4096            15.14%
#    7285  2675     -201.0964    45     -200.1184     -229.9162   639169   14.89%
#    7927  3096     -217.7919   131     -200.1184     -228.9383   685062   14.40%
#    8531  3545     -201.7849    71     -200.1184     -228.6479   735110   14.26%
#    9214  3846     -214.7839   128     -200.1184     -227.7124   771205   13.79%
#    9956  4451        cutoff           -200.1184     -227.0951   827848   13.48%
#   10700  4823     -201.2220   103     -200.1184     -226.5870   871810   13.23%
#   11431  5343     -221.1259   178     -200.1184     -226.1018   929865   12.98%
#   12250  5848     -218.9718   149     -200.1184     -225.6539   980090   12.76%
#   13063  6257     -214.4652    95     -200.1184     -225.1595  1019321   12.51%
#   13880  6790     -214.8540   104     -200.1184     -224.6483  1070628   12.26%
# Elapsed time = 37.92 sec. (25919.81 ticks, tree = 91.41 MB, solutions = 6)
#   14678  7291     -218.4775   116     -200.1184     -224.2069  1125697   12.04%
#   15515  7795     -201.6057   109     -200.1184     -223.9285  1171160   11.90%
#   16368  8368        cutoff           -200.1184     -223.5440  1231393   11.71%
#   17223  8784        cutoff           -200.1184     -223.3412  1271846   11.60%
#   18125  9330        cutoff           -200.1184     -223.0160  1329052   11.44%
#   19030  9783        cutoff           -200.1184     -222.7578  1373521   11.31%
#   19942 10251     -212.4379   130     -200.1184     -222.4697  1423408   11.17%
#   20882 11014     -211.0092   104     -200.1184     -222.1550  1490363   11.01%
#   21802 11422        cutoff           -200.1184     -221.9159  1531320   10.89%
#   22755 11860     -212.6508   124     -200.1184     -221.6293  1577301   10.75%
# Elapsed time = 51.62 sec. (35462.95 ticks, tree = 185.32 MB, solutions = 6)
#   23659 12516     -204.0696   101     -200.1184     -221.3416  1633633   10.61%
#   24617 12855     -207.1450    46     -200.1184     -221.1164  1670829   10.49%
#   25622 13464     -212.8689    91     -200.1184     -220.8893  1725599   10.38%
#   26475 14144     -212.0184   127     -200.1184     -220.7038  1793068   10.29%
#   27469 14559        cutoff           -200.1184     -220.4888  1844539   10.18%
#   28432 15019     -202.4792    55     -200.1184     -220.3376  1884371   10.10%
# * 28694+15350                         -200.2249     -220.2909            10.02%
#   29328 15348     -209.1127   118     -200.2249     -220.1471  1918188    9.95%
#   29815 15951     -207.8086    70     -200.2249     -220.0512  1984314    9.90%
#   29907 16006     -209.3294    92     -200.2249     -220.0166  1992295    9.88%
#   30776 16257     -202.3866    98     -200.2249     -219.8612  2015432    9.81%
# Elapsed time = 65.47 sec. (45016.34 ticks, tree = 270.73 MB, solutions = 7)
#   31738 16500        cutoff           -200.2249     -219.7537  2040028    9.75%
# * 32241 17186      integral     0     -203.0303     -219.6923  2106045    8.21%
#   32533 15284     -210.0152   116     -203.0303     -219.6477  2121168    8.18%
#   33378 15545     -207.2073    77     -203.0303     -219.4699  2158147    8.10%
#   33561 15749     -207.3587    84     -203.0303     -219.4699  2187218    8.10%
#   34516 16059     -209.4241   120     -203.0303     -219.2930  2222132    8.01%
#   35465 16537     -208.1460    91     -203.0303     -219.1557  2280611    7.94%
#   36297 16742     -203.8295    48     -203.0303     -219.0570  2307290    7.89%
#   36926 17188     -204.9006    72     -203.0303     -218.9445  2372970    7.84%
#   37806 17473     -207.2959    68     -203.0303     -218.8210  2403927    7.78%
#   38829 17576     -217.8056   143     -203.0303     -218.6802  2420297    7.71%
# Elapsed time = 79.35 sec. (54559.40 ticks, tree = 304.61 MB, solutions = 8)
#   39761 18027     -207.4161    95     -203.0303     -218.5121  2469166    7.63%
#   40688 18481     -204.1885    93     -203.0303     -218.3393  2530623    7.54%
#   41744 18898     -203.9635    71     -203.0303     -218.1382  2593827    7.44%
#   42694 19257     -205.0545    60     -203.0303     -217.9812  2638327    7.36%
# * 43394 19690      integral     0     -203.8589     -217.9177  2693877    6.90%
#   43651 19728        cutoff           -203.8589     -217.8824  2702008    6.88%
#   44122 19015     -207.2999    76     -203.8589     -217.8024  2748603    6.84%
#   45022 19312        cutoff           -203.8589     -217.5876  2791008    6.73%
#   46107 19579     -207.9098    47     -203.8589     -217.4395  2828794    6.66%
#   47168 19840     -216.5139    86     -203.8589     -217.2865  2866154    6.59%
#   48121 20500     -212.2319    96     -203.8589     -217.1793  2966807    6.53%
# Elapsed time = 93.20 sec. (64103.17 ticks, tree = 333.20 MB, solutions = 9)
#   49082 20670     -204.0121    56     -203.8589     -217.1476  2995461    6.52%
#   50105 21046     -204.6294    81     -203.8589     -216.9869  3058369    6.44%
#   51198 21312     -205.3149    90     -203.8589     -216.8389  3099052    6.37%
#   52171 21554     -206.1967    65     -203.8589     -216.6727  3129466    6.29%
#   53254 22022     -208.0687    71     -203.8589     -216.5355  3214245    6.22%
#   54217 22208        cutoff           -203.8589     -216.4339  3245122    6.17%
#   55292 22622     -205.8256   101     -203.8589     -216.3528  3321256    6.13%
#   56333 22976     -211.6054   117     -203.8589     -216.2235  3376357    6.07%
#   57380 23141     -205.3270    70     -203.8589     -216.0829  3405021    6.00%
#   58412 23670     -209.3641    77     -203.8589     -215.9330  3508581    5.92%
# Elapsed time = 106.75 sec. (73648.35 ticks, tree = 379.73 MB, solutions = 9)
#   59514 23968     -205.3149   108     -203.8589     -215.7878  3563396    5.85%
#   60575 24194     -212.9908   129     -203.8589     -215.6791  3600010    5.80%
#   61549 24414        cutoff           -203.8589     -215.5850  3642748    5.75%
#   62682 24563     -206.9247    63     -203.8589     -215.4652  3683145    5.69%
#   63788 24953     -204.4399    90     -203.8589     -215.3343  3759488    5.63%
#   64949 25052        cutoff           -203.8589     -215.1788  3778749    5.55%
#   66037 25411        cutoff           -203.8589     -215.0521  3842424    5.49%
#   67062 25726     -212.6855    93     -203.8589     -214.9615  3907251    5.45%
#   68134 25967     -206.4845    88     -203.8589     -214.9110  3964562    5.42%
#   69326 26104     -209.0568    99     -203.8589     -214.7752  3993768    5.35%
# Elapsed time = 120.61 sec. (83193.80 ticks, tree = 417.26 MB, solutions = 9)
#   70390 26387     -213.8597   118     -203.8589     -214.6510  4063906    5.29%
#   71469 26727     -209.7822    62     -203.8589     -214.4983  4130587    5.22%
#   72534 27002     -208.1638   113     -203.8589     -214.3586  4197914    5.15%
#   73571 27187        cutoff           -203.8589     -214.2759  4248381    5.11%
#   74719 27250        cutoff           -203.8589     -214.2068  4262163    5.08%
#   75869 27433     -209.0430    98     -203.8589     -214.0982  4308274    5.02%
#   77002 27834        cutoff           -203.8589     -213.9870  4394675    4.97%
#   78105 28015        cutoff           -203.8589     -213.8735  4456627    4.91%
#   79206 28110     -204.0680    51     -203.8589     -213.7568  4484381    4.86%
#   84074 29034     -204.7990   103     -203.8589     -213.3965  4722145    4.68%
# Elapsed time = 138.29 sec. (95597.18 ticks, tree = 459.19 MB, solutions = 9)
#   88935 29621     -211.9098   128     -203.8589     -212.9513  4917590    4.46%
#   93802 30187     -206.7234   113     -203.8589     -212.6104  5134737    4.29%
#   98574 30607     -206.8903    86     -203.8589     -212.2494  5333293    4.12%
#  103740 31077     -205.9327    80     -203.8589     -211.8737  5594941    3.93%
#  108809 31236        cutoff           -203.8589     -211.5416  5773446    3.77%
#  113916 31361     -206.1013    71     -203.8589     -211.1343  5996567    3.57%
#  119299 31295        cutoff           -203.8589     -210.7922  6200709    3.40%
# *121714 31199      integral     0     -205.7292     -210.6101  6326484    2.37%
#  124243 23654     -206.1610    78     -205.7292     -210.4066  6412459    2.27%
#  130104 21627        cutoff           -205.7292     -209.9905  6657028    2.07%
#  136290 19225        cutoff           -205.7292     -209.3303  6868184    1.75%
# Elapsed time = 195.15 sec. (133751.64 ticks, tree = 264.08 MB, solutions = 10)
#  143071 15855        cutoff           -205.7292     -208.5550  7093100    1.37%
#  151213 10138        cutoff           -205.7292     -207.5378  7333467    0.88%
#  161733  1056        cutoff           -205.7292     -205.9425  7526260    0.10%
#
# GUB cover cuts applied:  9
# Clique cuts applied:  38
# Cover cuts applied:  256
# Implied bound cuts applied:  16
# Flow cuts applied:  7
# Mixed integer rounding cuts applied:  17
# Zero-half cuts applied:  3
# Lift and project cuts applied:  3
# Gomory fractional cuts applied:  62
#
# Root node processing (before b&c):
#   Real time             =    2.29 sec. (1421.20 ticks)
# Parallel b&c, 8 threads:
#   Real time             =  213.44 sec. (144088.55 ticks)
#   Sync time (average)   =   17.56 sec.
#   Wait time (average)   =    0.16 sec.
#                           ------------
# Total (root+branch&cut) =  215.73 sec. (145509.75 ticks)
# Done!
# Time elapsed: 215.772130966

# %%
oldmodel, oldruntime = run_model(450, new_model=False)
# Out:
# Solving...
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 3 times.
# MIP Presolve eliminated 4220 rows and 580 columns.
# MIP Presolve modified 568 coefficients.
# Aggregator did 782 substitutions.
# Reduced MIP has 2348 rows, 1458 columns, and 7276 nonzeros.
# Reduced MIP has 30 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.02 sec. (17.71 ticks)
# Probing time = 0.00 sec. (0.14 ticks)
# Tried aggregator 1 time.
# MIP Presolve eliminated 1128 rows and 714 columns.
# Reduced MIP has 1220 rows, 744 columns, and 3974 nonzeros.
# Reduced MIP has 30 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (5.25 ticks)
# Probing time = 0.00 sec. (0.09 ticks)
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 8 threads.
# Root relaxation solution time = 0.02 sec. (21.26 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                           57.4177      294.0003           412.04%
#       0     0       66.8354    12       57.4177       66.8354      823   16.40%
# *     0+    0                           66.0000       66.8354             1.27%
# *     0+    0                           66.8354       66.8354             0.00%
#       0     0        cutoff             66.8354       66.8354      823    0.00%
# Elapsed time = 0.18 sec. (109.22 ticks, tree = 0.01 MB, solutions = 3)
#
# Root node processing (before b&c):
#   Real time             =    0.18 sec. (109.37 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.18 sec. (109.37 ticks)
# Done!
# Time elapsed: 0.238327980042

# %%
new_dfx, new_dfy, new_dfg = newmodel.return_solution()
old_dfx, old_dfy, old_dfg = oldmodel.return_solution()

# %% [markdown]
# ## Intersection Cell Network

# %% [markdown]
# ![title](img/4leg-intersection.png)

# %% [markdown]
# ## Setting the path of cells to check

# %%
_approach = SOUTHBOUND

_approach_terms = [
    'Left',
    'Through',
    'Right'
]

_cell_path = [
    (CELL_SOURCE,0,_approach),
    (CELL_NORMAL,0,_approach),
    (CELL_NORMAL,1,_approach),
    (CELL_NORMAL,2,_approach),
    (CELL_MOVEMENT,THROUGH_TURN,_approach),
    S_mapping((CELL_MOVEMENT,THROUGH_TURN,_approach))[0]
]

def movement_paths(approach):
    return [
        [
            (CELL_SOURCE,0,approach),
            (CELL_NORMAL,0,approach),
            (CELL_NORMAL,1,approach),
            (CELL_NORMAL,2,approach),
            (CELL_MOVEMENT,LEFT_TURN,approach),
            S_mapping((CELL_MOVEMENT,LEFT_TURN,approach))[0]
        ],
        [
            (CELL_SOURCE,0,approach),
            (CELL_NORMAL,0,approach),
            (CELL_NORMAL,1,approach),
            (CELL_NORMAL,2,approach),
            (CELL_MOVEMENT,THROUGH_TURN,approach),
            S_mapping((CELL_MOVEMENT,THROUGH_TURN,approach))[0]
        ],
        [
            (CELL_SOURCE,0,approach),
            (CELL_NORMAL,0,approach),
            (CELL_NORMAL,1,approach),
            (CELL_NORMAL,2,approach),
            (CELL_MOVEMENT,RIGHT_TURN,approach),
            S_mapping((CELL_MOVEMENT,RIGHT_TURN,approach))[0]
        ]
    ]

# %% [markdown]
# ## Comparing cell volumes

# %%
def plot_volume(dfx, cell_path=_cell_path, title="Volume", headless=False, filename='volume.png'):
    dfx_approach = pd.concat([
        dfx[dfx.cell == c].sort_values(by='timestep')
        for c in cell_path
    ]).pivot(index='timestep', columns='cell', values='volume')
    
    fig, axs = plt.subplots(1,2, figsize=(20,10))
    
    sns.lineplot(data=dfx_approach, ax=axs[0])
    sns.lineplot(data=dfx_approach.cumsum(), ax=axs[1])

    axs[0].set_title('Volume of cells')
    axs[0].set_xlabel('Timesteps')
    axs[0].set_ylabel('Instantaneous volume')
    axs[0].set_xticks(time_ticks, minor=True)

    axs[1].set_title('Volume of cells (cumulative)')
    axs[1].set_xlabel('Timesteps')
    axs[1].set_ylabel('Cumulative volume')
    axs[1].set_xticks(time_ticks, minor=True)
    
    fig.suptitle(title, fontsize=18)
    
    if headless:
        fig.savefig(IMAGE_PATH + filename)
        plt.close(fig)

# %% [markdown]
# ## Comparing flows

# %%
def plot_flow(dfy, cell_path=_cell_path, title="Flows", headless=False, filename='flow.png'):
    dfy_approach = pd.concat([
        dfy[dfy.cell_from == c].groupby(['cell_from', 'timestep']).agg({'flow': 'sum'}).sort_values(by='timestep')
        for c in cell_path
    ]).reset_index().pivot(index='timestep', columns='cell_from', values='flow')
    
    fig, axs = plt.subplots(1,2, figsize=(20,10))

    sns.lineplot(data=dfy_approach, ax=axs[0])
    sns.lineplot(data=dfy_approach.cumsum(), ax=axs[1])

    axs[0].set_title('Flow from cells')
    axs[0].set_xlabel('Timesteps')
    axs[0].set_ylabel('Instantaneous flow')
    axs[0].set_xticks(time_ticks, minor=True)

    axs[1].set_title('Flow from cells (cumulative)')
    axs[1].set_xlabel('Timesteps')
    axs[1].set_ylabel('Cumulative flow')
    axs[1].set_xticks(time_ticks, minor=True)
    
    fig.suptitle(title, fontsize=18)
    
    if headless:
        fig.savefig(IMAGE_PATH + filename)
        plt.close(fig)

# %% [markdown]
# ## Comparing specific green time

# %%
all_phases = [intToBinTuple(x) for x in range(8)]
all_phases_labels = [
    "Left, Westbound",
    "Through, Eastbound",
    "Left, Southbound",
    "Through, Southbound",
    "Left, Eastbound",
    "Through, Westbound",
    "Left, Northbound",
    "Through, Northbound",
]

def plot_greentime_map(dfg, title="Greentime maps", headless=False, filename='greentime.png', movements=True):
    fig, axs = plt.subplots(figsize=(18,8))

    dfg_matrix = dfg.T
    if movements:
        dfg_matrix = dfg_matrix.reindex(index=[
            (2,LEFT_TURN,EASTBOUND), (2,RIGHT_TURN,EASTBOUND), (2,THROUGH_TURN,EASTBOUND),
            (2,LEFT_TURN,NORTHBOUND), (2,RIGHT_TURN,NORTHBOUND), (2,THROUGH_TURN,NORTHBOUND),
            (2,LEFT_TURN,SOUTHBOUND), (2,RIGHT_TURN,SOUTHBOUND), (2,THROUGH_TURN,SOUTHBOUND),
            (2,LEFT_TURN,WESTBOUND), (2,RIGHT_TURN,WESTBOUND), (2,THROUGH_TURN,WESTBOUND),
        ])
    sns.heatmap(data=dfg_matrix)
    
    fig.suptitle(title, fontsize=18)
    
    if headless:
        fig.savefig(IMAGE_PATH + filename)
        plt.close(fig)

# %%
def plot_obj_values(obj_values, title, xaxis, xlabel, headless=True, filename='obj.png'):
    fig, axs = plt.subplots(1,2,figsize=(20,10))

    axs[0].plot(xaxis, [x[0] for x in obj_values])
    axs[0].set_title("Computed total delay")
    axs[0].set_ylabel("Total vehicle delay (timesteps)")
    axs[0].set_xlabel(xlabel)

    axs[1].plot(xaxis, [x[1] for x in obj_values])
    axs[1].set_title("Computed total throughput")
    axs[1].set_ylabel("Total vehicle throughput (veh)")
    axs[1].set_xlabel(xlabel)
    
    fig.suptitle(title, fontsize=18)
    
    if headless:
        fig.savefig(IMAGE_PATH + filename)
        plt.close(fig)

# %% [markdown]
# ## Saving dataframes

# %%
def save_df(df, filename):
    df.to_pickle(DF_PATH + filename + ".pkl")

# %% [markdown]
# ## Checking the parent model

# %%
plot_greentime_map(new_dfg)

# %% [markdown]
# ## 1. Checking the effect of flow weight

# %% [markdown]
# **VERDICT:** Inconclusive, but cursory examination of graphs reveal a flow weight of 0.6
#
# **Notes:**
# * For alpha = 1, objective function values dont vary with flow weight
# * For alpha = 0, delay values vary between 1350 and 1450; throughput values don't
# * Runtime graphs are erratic
# * Flow diagrams are more or less erratic, some flow weights (e.g. 0.4) give more erratic flow diagrams than others

# %% [markdown]
# ## 2. Checking the effect of traffic demand

# %% [markdown]
# ### Alpha = 1, Flow weight = 0.6, Demand = [450, 900]

# %%
demands = [x for x in range(450, 901, 50)]
demands2 = [x for x in range(950, 1801, 50)]

#runtimes = []
#obj_value_list = []
alpha = 1
flow_weight = 0.6

for d in demands2:
    dfx, dfy, dfg, dfparams, obj_values, runtime = run_model(demand=d, alpha=alpha, use=True, flow_weight=flow_weight)
    runtimes.append(runtime)
    obj_value_list.append(obj_values)
    
    generate_graphs(dfx, dfy, dfg, dfparams.capacity[(3,0,1)], dfparams.max_flow[(3,0,1)], d, alpha, flow_weight, folder='demands/')
    print("\n~~~\nDone with {}!\n~~~\n".format(d))
# Out:
# Solving...
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 2 times.
# MIP Presolve eliminated 1940 rows and 292 columns.
# MIP Presolve modified 752 coefficients.
# Aggregator did 128 substitutions.
# Reduced MIP has 3482 rows, 1860 columns, and 12232 nonzeros.
# Reduced MIP has 240 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.02 sec. (12.67 ticks)
# Found incumbent of value 3586.978307 after 0.04 sec. (26.16 ticks)
# Probing fixed 0 vars, tightened 142 bounds.
# Probing time = 0.00 sec. (0.61 ticks)
# Tried aggregator 2 times.
# MIP Presolve eliminated 604 rows and 104 columns.
# Aggregator did 88 substitutions.
# Reduced MIP has 2790 rows, 1668 columns, and 10524 nonzeros.
# Reduced MIP has 240 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (5.55 ticks)
# Probing time = 0.00 sec. (0.41 ticks)
# Tried aggregator 1 time.
# Reduced MIP has 2790 rows, 1668 columns, and 10524 nonzeros.
# Reduced MIP has 240 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (7.23 ticks)
# Probing time = 0.00 sec. (0.41 ticks)
# Clique table members: 120.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 8 threads.
# Root relaxation solution time = 0.17 sec. (180.02 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                         3586.9783    -6178.4869           272.25%
#       0     0      250.9872   133     3586.9783      250.9872       22   93.00%
# *     0+    0                          482.7204      250.9872            48.01%
# *     0+    0                          433.0188      250.9872            42.04%
#       0     0      262.7614   131      433.0188      Cuts: 50      357   39.32%
#       0     0      272.5653   126      433.0188      Cuts: 58      602   37.05%
#       0     0      276.3792   138      433.0188      Cuts: 47      684   36.17%
#       0     0      276.8484   138      433.0188       Cuts: 7      705   36.07%
# *     0+    0                          399.7518      276.8484            30.74%
# *     0+    0                          397.4954      276.8484            30.35%
# *     0+    0                          374.9942      276.8484            26.17%
#       0     2      276.8484   134      374.9942      281.0425      705   25.05%
# Elapsed time = 1.05 sec. (797.99 ticks, tree = 0.01 MB, solutions = 6)
#     162   103      334.5479    75      374.9942      281.0425    12839   25.05%
# *   326+  152                          364.5314      283.0952            22.34%
#     422   195      327.1018    74      364.5314      283.1071    34352   22.34%
# *   557+  208                          353.8973      283.1071            20.00%
#     659   260      319.2849    67      353.8973      288.2469    51450   18.55%
# *   666+  244                          352.4596      288.2469            18.22%
# *   810+  264                          343.8223      288.2469            16.16%
#     947   263      330.9858    81      343.8223      297.2274    66598   13.55%
# *  1053+  254                          342.9774      308.4011            10.08%
#    1286   354        cutoff            342.9774      318.2389    90028    7.21%
# *  1615   487      integral     0      342.8626      323.4676   107993    5.66%
#    1736   509      337.1915    48      342.8626      324.0657   113407    5.48%
# *  1767+  493                          341.3606      324.0657             5.07%
# *  1809+  504                          340.1846      324.0657             4.74%
# *  1820   475      integral     0      339.8833      324.0657   120435    4.65%
# *  1934+  467                          339.5699      324.0657             4.57%
# *  1939+  503                          339.5699      324.0657             4.57%
#    2140   507      336.5234    43      339.5699      328.5403   131293    3.25%
# *  2290+  515                          339.0086      328.9950             2.95%
# *  2322   476      integral     0      338.4061      329.2772   140807    2.70%
# *  2505   448      integral     0      338.3425      331.0189   144419    2.16%
#    2682   419      335.8076    28      338.3425      332.3252   155554    1.78%
# *  2738   432      integral     0      338.2789      332.9658   155189    1.57%
#
# Cover cuts applied:  130
# Implied bound cuts applied:  1
# Flow cuts applied:  20
# Mixed integer rounding cuts applied:  25
# Zero-half cuts applied:  10
# Lift and project cuts applied:  3
# Gomory fractional cuts applied:  17
#
# Root node processing (before b&c):
#   Real time             =    1.05 sec. (795.95 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    3.86 sec. (2091.63 ticks)
#   Sync time (average)   =    0.98 sec.
#   Wait time (average)   =    0.03 sec.
#                           ------------
# Total (root+branch&cut) =    4.91 sec. (2887.58 ticks)
# Done!
# Time elapsed: 5.00232481956
#
# ~~~
# Done with 950!
# ~~~
#
# Solving...
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 2 times.
# MIP Presolve eliminated 1940 rows and 292 columns.
# MIP Presolve modified 752 coefficients.
# Aggregator did 128 substitutions.
# Reduced MIP has 3482 rows, 1860 columns, and 12232 nonzeros.
# Reduced MIP has 240 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.02 sec. (12.67 ticks)
# Found incumbent of value 3771.173391 after 0.03 sec. (26.16 ticks)
# Probing fixed 0 vars, tightened 142 bounds.
# Probing time = 0.00 sec. (0.61 ticks)
# Tried aggregator 2 times.
# MIP Presolve eliminated 604 rows and 104 columns.
# Aggregator did 88 substitutions.
# Reduced MIP has 2790 rows, 1668 columns, and 10524 nonzeros.
# Reduced MIP has 240 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (5.55 ticks)
# Probing time = 0.00 sec. (0.41 ticks)
# Tried aggregator 1 time.
# Reduced MIP has 2790 rows, 1668 columns, and 10524 nonzeros.
# Reduced MIP has 240 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (7.23 ticks)
# Probing time = 0.00 sec. (0.41 ticks)
# Clique table members: 120.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 8 threads.
# Root relaxation solution time = 0.18 sec. (190.39 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                         3771.1734    -6167.5403           263.54%
#       0     0      390.2535   142     3771.1734      390.2535       25   89.65%
# *     0+    0                          570.1105      390.2535            31.55%
#       0     0      399.0229   129      570.1105      Cuts: 62      200   29.26%
# *     0+    0                          500.0647      403.3091            19.35%
#       0     0      407.1708   126      500.0647      Cuts: 50      392   18.58%
#       0     0      413.5704   134      500.0647      Cuts: 32      546   17.30%
#       0     0      413.9899   127      500.0647      Cuts: 34      605   17.21%
#       0     0      414.1785   127      500.0647      Cuts: 16      629   17.18%
# *     0+    0                          494.7162      414.1785            16.28%
#       0     2      414.1785   127      494.7162      414.2757      629   16.26%
# Elapsed time = 1.15 sec. (841.71 ticks, tree = 0.01 MB, solutions = 4)
#     153    63      470.8036    67      494.7162      422.1599    12125   14.67%
# *   364+  206                          493.7388      438.3750            11.21%
# *   401+  190                          484.0614      438.3750             9.44%
#     451   246      477.6956    67      484.0614      438.3750    36259    9.44%
# *   576+  244                          482.0686      443.0912             8.09%
#     755   297      480.7276    54      482.0686      449.2767    55527    6.80%
# *   964+  373                          478.8314      455.1480             4.95%
# *   982   379      integral     0      478.5303      455.7524    73644    4.76%
# *   988   378      integral     0      478.2292      456.1529    74798    4.62%
#    1082   397        cutoff            478.2292      456.2394    80399    4.60%
#    1468   520      476.2326    45      478.2292      461.0498   101857    3.59%
# *  1501+  490                          477.7920      461.5256             3.40%
# *  1607+  523                          477.7920      462.4485             3.21%
#    1831   560      472.9749    71      477.7920      464.4255   117779    2.80%
#    2239   657      474.5247    32      477.7920      466.7770   144093    2.31%
# *  2362   684      integral     0      475.5036      467.7233   150103    1.64%
#    2731   380        cutoff            475.5036      470.3563   166787    1.08%
#    3209   162        cutoff            475.5036      472.7539   181591    0.58%
#
# Cover cuts applied:  138
# Implied bound cuts applied:  2
# Flow cuts applied:  25
# Mixed integer rounding cuts applied:  23
# Zero-half cuts applied:  6
# Lift and project cuts applied:  4
# Gomory fractional cuts applied:  18
#
# Root node processing (before b&c):
#   Real time             =    1.15 sec. (839.63 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    3.43 sec. (2196.56 ticks)
#   Sync time (average)   =    0.66 sec.
#   Wait time (average)   =    0.02 sec.
#                           ------------
# Total (root+branch&cut) =    4.58 sec. (3036.19 ticks)
# Done!
# Time elapsed: 4.64941382408
#
# ~~~
# Done with 1000!
# ~~~
#
# Solving...
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 2 times.
# MIP Presolve eliminated 1928 rows and 292 columns.
# MIP Presolve modified 752 coefficients.
# Aggregator did 116 substitutions.
# Reduced MIP has 3506 rows, 1872 columns, and 12248 nonzeros.
# Reduced MIP has 240 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.02 sec. (12.64 ticks)
# Found incumbent of value 3954.920869 after 0.03 sec. (26.41 ticks)
# Probing fixed 0 vars, tightened 140 bounds.
# Probing time = 0.00 sec. (0.61 ticks)
# Tried aggregator 2 times.
# MIP Presolve eliminated 604 rows and 104 columns.
# Aggregator did 88 substitutions.
# Reduced MIP has 2814 rows, 1680 columns, and 10540 nonzeros.
# Reduced MIP has 240 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (5.56 ticks)
# Probing time = 0.00 sec. (0.41 ticks)
# Tried aggregator 1 time.
# Reduced MIP has 2814 rows, 1680 columns, and 10540 nonzeros.
# Reduced MIP has 240 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (7.26 ticks)
# Probing time = 0.00 sec. (0.41 ticks)
# Clique table members: 120.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 8 threads.
# Root relaxation solution time = 0.17 sec. (185.25 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                         3954.9209    -6163.9185           255.85%
#       0     0      529.6942   127     3954.9209      529.6942       25   86.61%
# *     0+    0                          741.7917      529.6942            28.59%
#       0     0      539.8377   132      741.7917      Cuts: 69      214   27.23%
#       0     0      543.6331   114      741.7917      Cuts: 47      397   26.71%
# *     0+    0                          733.3251      543.6331            25.87%
# *     0+    0                          651.8688      543.6331            16.60%
#       0     0      547.8324   119      651.8688      Cuts: 41      515   15.96%
#       0     0      548.3544   125      651.8688      Cuts: 30      575   15.88%
#       0     0      548.7876   135      651.8688      Cuts: 14      644   15.81%
#       0     0      548.7954   133      651.8688      Cuts: 26      655   15.81%
#       0     0      548.7954   132      651.8688       Cuts: 2      663   15.81%
# *     0+    0                          622.1418      548.7954            11.79%
#       0     2      548.7954   130      622.1418      552.3438      663   11.22%
# Elapsed time = 1.53 sec. (1058.97 ticks, tree = 0.01 MB, solutions = 5)
# *   122+   64                          618.8073      559.2099             9.63%
#     181    93        cutoff            618.8073      565.7900    16880    8.57%
#     460   224        cutoff            618.8073      582.8592    37102    5.81%
#     783   367        cutoff            618.8073      590.4284    57493    4.59%
#     961   420      595.4569    89      618.8073      590.9309    62489    4.50%
#    1277   621        cutoff            618.8073      593.2246    85838    4.13%
# *  1635   766      integral     0      618.6332      598.3309   104589    3.28%
#    2036   895        cutoff            618.6332      599.9657   125052    3.02%
# *  2193+  906                          618.5843      599.9657             3.01%
#    2193   946      614.3462    75      618.5843      599.9657   135324    3.01%
# *  2195+  885                          618.5843      599.9657             3.01%
#    2299   983      618.5209    64      618.5843      600.2271   138580    2.97%
# *  2682+ 1113                          618.4429      602.7378             2.54%
# *  2714+ 1134                          616.9223      602.9951             2.26%
# *  2815  1012      integral     0      616.4473      603.3539   164316    2.12%
# Elapsed time = 5.48 sec. (3538.79 ticks, tree = 0.80 MB, solutions = 11)
# *  3534+ 1113                          615.5266      606.2745             1.50%
# *  3543   972      integral     0      615.0516      606.2745   203179    1.43%
# *  4189+  885                          614.8623      609.0979             0.94%
# *  4204   826      integral     0      614.6248      609.0979   229857    0.90%
#
# Cover cuts applied:  166
# Implied bound cuts applied:  5
# Flow cuts applied:  36
# Mixed integer rounding cuts applied:  26
# Zero-half cuts applied:  4
# Lift and project cuts applied:  5
# Gomory fractional cuts applied:  12
#
# Root node processing (before b&c):
#   Real time             =    1.48 sec. (1056.85 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    5.97 sec. (3626.85 ticks)
#   Sync time (average)   =    1.25 sec.
#   Wait time (average)   =    0.02 sec.
#                           ------------
# Total (root+branch&cut) =    7.45 sec. (4683.70 ticks)
# Done!
# Time elapsed: 7.52092790604
#
# ~~~
# Done with 1050!
# ~~~
#
# Solving...
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 2 times.
# MIP Presolve eliminated 1928 rows and 292 columns.
# MIP Presolve modified 752 coefficients.
# Aggregator did 116 substitutions.
# Reduced MIP has 3506 rows, 1872 columns, and 12248 nonzeros.
# Reduced MIP has 240 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.02 sec. (12.64 ticks)
# Found incumbent of value 4138.222372 after 0.03 sec. (26.41 ticks)
# Probing fixed 0 vars, tightened 140 bounds.
# Probing time = 0.00 sec. (0.61 ticks)
# Tried aggregator 2 times.
# MIP Presolve eliminated 604 rows and 104 columns.
# Aggregator did 88 substitutions.
# Reduced MIP has 2814 rows, 1680 columns, and 10540 nonzeros.
# Reduced MIP has 240 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (5.56 ticks)
# Probing time = 0.00 sec. (0.41 ticks)
# Tried aggregator 1 time.
# Reduced MIP has 2814 rows, 1680 columns, and 10540 nonzeros.
# Reduced MIP has 240 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (7.26 ticks)
# Probing time = 0.00 sec. (0.41 ticks)
# Clique table members: 120.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 8 threads.
# Root relaxation solution time = 0.21 sec. (183.95 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                         4138.2224    -6153.0324           248.69%
#       0     0      668.9597   108     4138.2224      668.9597       23   83.83%
# *     0+    0                          906.0093      668.9597            26.16%
#       0     0      681.4461   117      906.0093      Cuts: 57      431   24.79%
# *     0+    0                          864.9763      681.4461            21.22%
#       0     0      685.6919   120      864.9763      Cuts: 46      632   20.73%
#       0     0      686.2238   122      864.9763      Cuts: 39      718   20.67%
# *     0+    0                          803.4383      686.2238            14.59%
#       0     0      686.2478   126      803.4383      Cuts: 22      743   14.59%
# *     0+    0                          792.5426      686.2478            13.41%
#       0     0      686.2478   119      792.5426   ZeroHalf: 2      749   13.41%
#       0     0      686.2478   125      792.5426      Cuts: 35      790   13.41%
# *     0+    0                          754.4472      686.2478             9.04%
#       0     2      686.2478   120      754.4472      692.4925      790    8.21%
# Elapsed time = 1.22 sec. (938.65 ticks, tree = 0.01 MB, solutions = 6)
#     238   110      753.5922    73      754.4472      693.7289    16406    8.05%
#     540   176      740.9247    75      754.4472      705.3572    33720    6.51%
# *   606   203      integral     0      754.2567      705.3572    36964    6.48%
# *   733   280      integral     0      752.0011      711.9212    45388    5.33%
# *   743   311      integral     0      751.7636      711.9212    50159    5.30%
# *   752   310      integral     0      751.5262      711.9212    51002    5.27%
# *   763   309      integral     0      750.9195      716.0284    51594    4.65%
#     827   305      746.1149    56      750.9195      716.4207    52937    4.59%
# *  1164+  424                          750.3146      726.0910             3.23%
# *  1197   423      integral     0      748.3426      726.5139    75945    2.92%
#    1197   416      745.9355    52      748.3426      726.5139    70354    2.92%
#    1645   494      747.2945    40      748.3426      733.3267    91905    2.01%
# *  1939+  610                          745.6121      735.7888             1.32%
# *  1949+  610                          745.0053      735.7888             1.24%
#    2043   390        cutoff            745.0053      735.9941   120680    1.21%
# *  2096+  618                          745.0053      735.9941             1.21%
#    2532   307        cutoff            745.0053      740.7628   141905    0.57%
#
# Cover cuts applied:  144
# Implied bound cuts applied:  6
# Flow cuts applied:  28
# Mixed integer rounding cuts applied:  36
# Zero-half cuts applied:  6
# Lift and project cuts applied:  3
# Gomory fractional cuts applied:  6
#
# Root node processing (before b&c):
#   Real time             =    1.19 sec. (936.63 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    3.00 sec. (1847.43 ticks)
#   Sync time (average)   =    0.58 sec.
#   Wait time (average)   =    0.02 sec.
#                           ------------
# Total (root+branch&cut) =    4.20 sec. (2784.06 ticks)
# Done!
# Time elapsed: 4.26523518562
#
# ~~~
# Done with 1100!
# ~~~
#
# Solving...
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 2 times.
# MIP Presolve eliminated 1928 rows and 292 columns.
# MIP Presolve modified 752 coefficients.
# Aggregator did 116 substitutions.
# Reduced MIP has 3506 rows, 1872 columns, and 12248 nonzeros.
# Reduced MIP has 240 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.02 sec. (12.64 ticks)
# Found incumbent of value 4321.079522 after 0.04 sec. (26.41 ticks)
# Probing fixed 0 vars, tightened 140 bounds.
# Probing time = 0.00 sec. (0.61 ticks)
# Tried aggregator 2 times.
# MIP Presolve eliminated 604 rows and 104 columns.
# Aggregator did 88 substitutions.
# Reduced MIP has 2814 rows, 1680 columns, and 10540 nonzeros.
# Reduced MIP has 240 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (5.56 ticks)
# Probing time = 0.00 sec. (0.41 ticks)
# Tried aggregator 1 time.
# Reduced MIP has 2814 rows, 1680 columns, and 10540 nonzeros.
# Reduced MIP has 240 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (7.26 ticks)
# Probing time = 0.00 sec. (0.41 ticks)
# Clique table members: 120.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 8 threads.
# Root relaxation solution time = 0.17 sec. (193.28 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                         4321.0795    -6142.1806           242.14%
#       0     0      808.0343   111     4321.0795      808.0343       26   81.30%
# *     0+    0                         1001.6676      808.0343            19.33%
# *     0+    0                          977.5732      808.0343            17.34%
#       0     0      816.6373   124      977.5732      Cuts: 57      254   16.46%
# *     0+    0                          905.2837      816.6373             9.79%
#       0     0      826.1597   139      905.2837      Cuts: 68      687    8.74%
#       0     0      827.3265   142      905.2837      Cuts: 59      807    8.61%
#       0     0      827.3265   142      905.2837       Cuts: 4      809    8.61%
# *     0+    0                          896.0199      827.3265             7.67%
#       0     2      827.3265   128      896.0199      828.0101      809    7.59%
# Elapsed time = 1.20 sec. (904.85 ticks, tree = 0.01 MB, solutions = 5)
# *   194+   88                          891.8014      831.2172             6.79%
#     194    90      857.3214    53      891.8014      831.2172    13302    6.79%
# *   309+  166                          887.5077      831.2172             6.34%
# *   412+  170                          884.2023      831.2172             5.99%
#     463   208      874.0638    67      884.2023      837.8638    35883    5.24%
# *   599+  235                          883.9019      846.9283             4.18%
#     788   339        cutoff            883.9019      848.3337    53605    4.02%
# *   952+  449                          880.7817      860.8700             2.26%
# *   985   394      integral     0      880.5443      861.8657    68992    2.12%
#    1158   408      876.1734    93      880.5443      864.4623    75337    1.83%
#    1588   505      871.0249    70      880.5443      869.0350   104105    1.31%
# *  1752+  514                          877.8171      869.3047             0.97%
#    1891   395        cutoff            877.8171      870.2815   115616    0.86%
#    2371   263        cutoff            877.8171      873.4182   136340    0.50%
#    2648    91        cutoff            877.8171      875.0497   141774    0.32%
#
# Cover cuts applied:  148
# Implied bound cuts applied:  2
# Flow cuts applied:  33
# Mixed integer rounding cuts applied:  24
# Zero-half cuts applied:  7
# Lift and project cuts applied:  6
# Gomory fractional cuts applied:  8
#
# Root node processing (before b&c):
#   Real time             =    1.18 sec. (902.77 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    3.09 sec. (1970.34 ticks)
#   Sync time (average)   =    0.58 sec.
#   Wait time (average)   =    0.02 sec.
#                           ------------
# Total (root+branch&cut) =    4.27 sec. (2873.11 ticks)
# Done!
# Time elapsed: 4.34226202965
#
# ~~~
# Done with 1150!
# ~~~
#
# Solving...
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 2 times.
# MIP Presolve eliminated 1928 rows and 292 columns.
# MIP Presolve modified 752 coefficients.
# Aggregator did 116 substitutions.
# Reduced MIP has 3506 rows, 1872 columns, and 12248 nonzeros.
# Reduced MIP has 240 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.02 sec. (12.64 ticks)
# Found incumbent of value 4503.493932 after 0.03 sec. (26.41 ticks)
# Probing fixed 0 vars, tightened 140 bounds.
# Probing time = 0.00 sec. (0.61 ticks)
# Tried aggregator 2 times.
# MIP Presolve eliminated 604 rows and 104 columns.
# Aggregator did 88 substitutions.
# Reduced MIP has 2814 rows, 1680 columns, and 10540 nonzeros.
# Reduced MIP has 240 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (5.56 ticks)
# Probing time = 0.00 sec. (0.41 ticks)
# Tried aggregator 1 time.
# Reduced MIP has 2814 rows, 1680 columns, and 10540 nonzeros.
# Reduced MIP has 240 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (7.26 ticks)
# Probing time = 0.00 sec. (0.41 ticks)
# Clique table members: 120.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 8 threads.
# Root relaxation solution time = 0.17 sec. (184.33 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                         4503.4939    -6131.3632           236.15%
#       0     0      946.6915   116     4503.4939      946.6915       26   78.98%
# *     0+    0                         1160.3120      946.6915            18.41%
#       0     0      955.5222   137     1160.3120      Cuts: 54      260   17.65%
#       0     0      960.8585   114     1160.3120      Cuts: 60      440   17.19%
#       0     0      961.5300   120     1160.3120      Cuts: 24      491   17.13%
#       0     0      961.5300   120     1160.3120    MIRcuts: 5      495   17.13%
# *     0+    0                         1131.5134      961.5300            15.02%
# *     0+    0                         1091.7298      961.5300            11.93%
# *     0+    0                         1074.1740      961.5300            10.49%
# *     0+    0                         1037.2255      961.5300             7.30%
#       0     2      961.5300   120     1037.2255      962.0271      495    7.25%
# Elapsed time = 0.98 sec. (748.50 ticks, tree = 0.01 MB, solutions = 6)
# *    42+    2                         1026.9194      962.0271             6.32%
#     188    54     1022.8657    65     1026.9194      968.4400    14413    5.69%
# *   294+  103                         1020.9205      968.4400             5.14%
# *   388   157      integral     0     1020.1619      974.8533    27354    4.44%
# *   581+  190                         1018.7480      979.7956             3.82%
# *   664+  262                         1018.4320      984.5655             3.33%
#     682   285        cutoff           1018.4320      986.1407    47702    3.17%
# *   771+  304                         1016.3725      993.3827             2.26%
# *   972+  330                         1015.8476      993.7264             2.18%
# *   978+  317                         1015.6104      993.7264             2.15%
#    1033   375     1011.0567    40     1015.6104      993.9607    65615    2.13%
# *  1052+  385                         1015.3731      993.9607             2.11%
#    1465   513     1012.6468    61     1015.3731      998.9044    83860    1.62%
#    1859   607        cutoff           1015.3731     1002.9231   105099    1.23%
#    1971   615     1010.4841    53     1015.3731     1004.9162   114038    1.03%
# *  2074+  605                         1013.5260     1005.1672             0.82%
# *  2283   430      integral     0     1013.0515     1006.0265   124980    0.69%
#    2942   214        cutoff           1013.0515     1010.9938   142530    0.20%
#
# Cover cuts applied:  140
# Implied bound cuts applied:  7
# Flow cuts applied:  21
# Mixed integer rounding cuts applied:  36
# Zero-half cuts applied:  10
# Lift and project cuts applied:  3
# Gomory fractional cuts applied:  9
#
# Root node processing (before b&c):
#   Real time             =    0.97 sec. (746.51 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    3.43 sec. (2183.39 ticks)
#   Sync time (average)   =    0.77 sec.
#   Wait time (average)   =    0.03 sec.
#                           ------------
# Total (root+branch&cut) =    4.40 sec. (2929.91 ticks)
# Done!
# Time elapsed: 4.47955608368
#
# ~~~
# Done with 1200!
# ~~~
#
# Solving...
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 2 times.
# MIP Presolve eliminated 1928 rows and 292 columns.
# MIP Presolve modified 752 coefficients.
# Aggregator did 116 substitutions.
# Reduced MIP has 3506 rows, 1872 columns, and 12248 nonzeros.
# Reduced MIP has 240 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.02 sec. (12.64 ticks)
# Found incumbent of value 4685.467207 after 0.03 sec. (26.41 ticks)
# Probing fixed 0 vars, tightened 140 bounds.
# Probing time = 0.00 sec. (0.61 ticks)
# Tried aggregator 2 times.
# MIP Presolve eliminated 604 rows and 104 columns.
# Aggregator did 88 substitutions.
# Reduced MIP has 2814 rows, 1680 columns, and 10540 nonzeros.
# Reduced MIP has 240 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (5.56 ticks)
# Probing time = 0.00 sec. (0.41 ticks)
# Tried aggregator 1 time.
# Reduced MIP has 2814 rows, 1680 columns, and 10540 nonzeros.
# Reduced MIP has 240 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (7.26 ticks)
# Probing time = 0.00 sec. (0.41 ticks)
# Clique table members: 120.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 8 threads.
# Root relaxation solution time = 0.17 sec. (188.14 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                         4685.4672    -6120.5801           230.63%
#       0     0     1084.9557    82     4685.4672     1084.9557       25   76.84%
# *     0+    0                         1436.8475     1084.9557            24.49%
# *     0+    0                         1332.3543     1084.9557            18.57%
#       0     0     1088.6346   110     1332.3543      Cuts: 39      473   18.29%
#       0     0     1092.1919   108     1332.3543      Cuts: 38      568   18.03%
#       0     0     1092.5903   125     1332.3543      Cuts: 11      600   18.00%
# *     0+    0                         1314.4163     1092.5903            16.88%
# *     0+    0                         1239.5025     1092.5903            11.85%
#       0     0     1092.7698   128     1239.5025      Cuts: 27      629   11.84%
#       0     0     1093.8793   112     1239.5025      Cuts: 19      700   11.75%
#       0     0     1093.8793   141     1239.5025      Cuts: 11      724   11.75%
# *     0+    0                         1176.3545     1093.8793             7.01%
#       0     0     1093.9318   128     1176.3545      Cuts: 10      742    7.01%
#       0     0     1096.4833   139     1176.3545      Cuts: 41      852    6.79%
#       0     0     1096.9302   136     1176.3545      Cuts: 16      913    6.75%
#       0     0     1096.9644   132     1176.3545      Cuts: 28      966    6.75%
# *     0+    0                         1152.7236     1096.9644             4.84%
#       0     2     1096.9644   115     1152.7236     1101.2170      966    4.47%
# Elapsed time = 1.20 sec. (877.68 ticks, tree = 0.01 MB, solutions = 7)
#     227   107     1141.9069    63     1152.7236     1111.0651    17509    3.61%
# *   387   195      integral     0     1152.0779     1114.0134    29019    3.30%
# *   714+  334                         1150.2179     1115.2292             3.04%
# *   754   323      integral     0     1149.6912     1119.3544    47507    2.64%
# *   760   330      integral     0     1149.3909     1119.3544    49265    2.61%
#    1135   418     1143.8273    31     1149.3909     1128.3281    67367    1.83%
# *  1436   499      integral     0     1148.9879     1137.1453    81902    1.03%
# *  1654   542      integral     0     1148.3526     1137.8039    92028    0.92%
# *  1658   524      integral     0     1147.8782     1137.8039    93827    0.88%
#    2139   476        cutoff           1147.8782     1140.9748   110806    0.60%
#
# Cover cuts applied:  136
# Implied bound cuts applied:  5
# Flow cuts applied:  21
# Mixed integer rounding cuts applied:  33
# Zero-half cuts applied:  2
# Lift and project cuts applied:  6
# Gomory fractional cuts applied:  5
#
# Root node processing (before b&c):
#   Real time             =    1.17 sec. (875.56 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    3.30 sec. (1885.02 ticks)
#   Sync time (average)   =    0.76 sec.
#   Wait time (average)   =    0.01 sec.
#                           ------------
# Total (root+branch&cut) =    4.46 sec. (2760.58 ticks)
# Done!
# Time elapsed: 4.53609991074
#
# ~~~
# Done with 1250!
# ~~~
#
# Solving...
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 2 times.
# MIP Presolve eliminated 1928 rows and 292 columns.
# MIP Presolve modified 752 coefficients.
# Aggregator did 116 substitutions.
# Reduced MIP has 3506 rows, 1872 columns, and 12248 nonzeros.
# Reduced MIP has 240 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.02 sec. (12.64 ticks)
# Found incumbent of value 4867.000948 after 0.03 sec. (26.41 ticks)
# Probing fixed 0 vars, tightened 140 bounds.
# Probing time = 0.00 sec. (0.61 ticks)
# Tried aggregator 2 times.
# MIP Presolve eliminated 604 rows and 104 columns.
# Aggregator did 88 substitutions.
# Reduced MIP has 2814 rows, 1680 columns, and 10540 nonzeros.
# Reduced MIP has 240 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (5.56 ticks)
# Probing time = 0.01 sec. (0.41 ticks)
# Tried aggregator 1 time.
# Reduced MIP has 2814 rows, 1680 columns, and 10540 nonzeros.
# Reduced MIP has 240 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (7.26 ticks)
# Probing time = 0.00 sec. (0.41 ticks)
# Clique table members: 120.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 8 threads.
# Root relaxation solution time = 0.18 sec. (193.43 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                         4867.0009    -6109.8310           225.54%
#       0     0     1265.4102    84     4867.0009     1265.4102       25   74.00%
# *     0+    0                         1502.3398     1265.4102            15.77%
#       0     0     1267.5545   114     1502.3398      Cuts: 48      403   15.63%
#       0     0     1272.9019   125     1502.3398      Cuts: 57      713   15.27%
# *     0+    0                         1421.3488     1272.9019            10.44%
# *     0+    0                         1362.7174     1272.9019             6.59%
#       0     0     1273.3286   138     1362.7174      Cuts: 35      804    6.56%
#       0     0     1273.7069   136     1362.7174      Cuts: 22      828    6.53%
# *     0+    0                         1354.8967     1273.7069             5.99%
#       0     2     1273.7069   115     1354.8967     1276.6928      828    5.77%
# Elapsed time = 1.09 sec. (815.32 ticks, tree = 0.01 MB, solutions = 5)
# *    81+   50                         1336.8891     1282.7367             4.05%
# *   112+   50                         1334.0990     1282.7367             3.85%
# *   145+   76                         1330.4961     1282.7367             3.59%
# *   151+   81                         1328.8189     1282.7367             3.47%
# *   170   107      integral     0     1328.7824     1282.7367    15580    3.47%
# *   176   107      integral     0     1328.1669     1282.7367    15714    3.42%
# *   263+  106                         1327.1219     1282.7367             3.34%
#     503   245     1319.6946    27     1327.1219     1299.9470    35813    2.05%
# *   647   306      integral     0     1327.0078     1300.1181    40601    2.03%
# *   655   328      integral     0     1326.7707     1303.1423    42907    1.78%
# *  1026   455      integral     0     1326.6547     1307.5755    59307    1.44%
# *  1275+  529                         1326.4331     1309.3979             1.28%
#    1500   611     1317.1555    28     1326.4331     1311.1045    79770    1.16%
# *  1892+  710                         1323.5278     1313.3110             0.77%
#    1955   733     1324.3585    26     1323.5278     1313.4459   102239    0.76%
#    2474   557     1322.2054    43     1323.5278     1316.5792   126821    0.53%
# *  2547   542      integral     0     1322.7585     1316.5792   129551    0.47%
# Elapsed time = 4.03 sec. (2317.79 ticks, tree = 0.30 MB, solutions = 20)
# *  2782   440      integral     0     1322.5214     1316.5792   137858    0.45%
#
# Cover cuts applied:  148
# Implied bound cuts applied:  1
# Flow cuts applied:  21
# Mixed integer rounding cuts applied:  16
# Zero-half cuts applied:  7
# Lift and project cuts applied:  4
# Gomory fractional cuts applied:  7
#
# Root node processing (before b&c):
#   Real time             =    1.08 sec. (813.41 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    4.20 sec. (2180.78 ticks)
#   Sync time (average)   =    1.34 sec.
#   Wait time (average)   =    0.02 sec.
#                           ------------
# Total (root+branch&cut) =    5.28 sec. (2994.19 ticks)
# Done!
# Time elapsed: 5.35301804543
#
# ~~~
# Done with 1300!
# ~~~
#
# Solving...
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 2 times.
# MIP Presolve eliminated 1928 rows and 292 columns.
# MIP Presolve modified 752 coefficients.
# Aggregator did 116 substitutions.
# Reduced MIP has 3506 rows, 1872 columns, and 12248 nonzeros.
# Reduced MIP has 240 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.02 sec. (12.64 ticks)
# Found incumbent of value 5048.096743 after 0.03 sec. (26.41 ticks)
# Probing fixed 0 vars, tightened 140 bounds.
# Probing time = 0.00 sec. (0.61 ticks)
# Tried aggregator 2 times.
# MIP Presolve eliminated 604 rows and 104 columns.
# Aggregator did 88 substitutions.
# Reduced MIP has 2814 rows, 1680 columns, and 10540 nonzeros.
# Reduced MIP has 240 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (5.56 ticks)
# Probing time = 0.00 sec. (0.41 ticks)
# Tried aggregator 1 time.
# Reduced MIP has 2814 rows, 1680 columns, and 10540 nonzeros.
# Reduced MIP has 240 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (7.26 ticks)
# Probing time = 0.00 sec. (0.41 ticks)
# Clique table members: 120.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 8 threads.
# Root relaxation solution time = 0.23 sec. (198.37 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                         5048.0967    -6099.1159           220.82%
#       0     0     1448.2974   104     5048.0967     1448.2974       27   71.31%
# *     0+    0                         1756.4079     1448.2974            17.54%
# *     0+    0                         1666.6679     1448.2974            13.10%
#       0     0     1448.7730   106     1666.6679      Cuts: 10      206   12.98%
#       0     0     1450.8655   116     1666.6679      Cuts: 50      499   12.95%
#       0     0     1450.8655   104     1666.6679      Cuts: 36      512   12.95%
# *     0+    0                         1538.2635     1450.8655             5.68%
#       0     0     1450.9071   111     1538.2635      Cuts: 13      529    5.68%
#       0     0     1452.6111   112     1538.2635      Cuts: 10      640    5.57%
#       0     0     1452.6111   104     1538.2635      Cuts: 29      654    5.57%
# *     0+    0                         1538.2154     1452.6111             5.57%
#       0     0     1452.6117   117     1538.2154       Cuts: 8      661    5.57%
# *     0+    0                         1508.1996     1452.6117             3.69%
#       0     2     1452.6117   111     1508.1996     1459.9265      661    3.20%
# Elapsed time = 1.22 sec. (886.09 ticks, tree = 0.01 MB, solutions = 6)
# *    92+   49                         1506.9435     1471.7200             2.34%
# *   118+   49                         1502.2963     1471.7200             2.04%
#     295   132        cutoff           1502.2963     1471.7200    11754    2.04%
#     696   291     1499.9172    48     1502.2963     1486.5677    24626    1.05%
# *   708+  239                         1497.4992     1486.5677             0.73%
#    1184   288     1495.4026    20     1497.4992     1487.5008    36631    0.67%
#    1555   267        cutoff           1497.4992     1492.7182    44525    0.32%
#
# Cover cuts applied:  109
# Flow cuts applied:  10
# Mixed integer rounding cuts applied:  23
# Zero-half cuts applied:  19
# Lift and project cuts applied:  5
# Gomory fractional cuts applied:  9
#
# Root node processing (before b&c):
#   Real time             =    1.20 sec. (883.96 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    1.99 sec. (1157.41 ticks)
#   Sync time (average)   =    0.48 sec.
#   Wait time (average)   =    0.01 sec.
#                           ------------
# Total (root+branch&cut) =    3.19 sec. (2041.37 ticks)
# Done!
# Time elapsed: 3.25663304329
#
# ~~~
# Done with 1350!
# ~~~
#
# Solving...
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 2 times.
# MIP Presolve eliminated 1928 rows and 292 columns.
# MIP Presolve modified 752 coefficients.
# Aggregator did 116 substitutions.
# Reduced MIP has 3506 rows, 1872 columns, and 12248 nonzeros.
# Reduced MIP has 240 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.02 sec. (12.64 ticks)
# Found incumbent of value 5228.756176 after 0.04 sec. (26.41 ticks)
# Probing fixed 0 vars, tightened 140 bounds.
# Probing time = 0.00 sec. (0.61 ticks)
# Tried aggregator 2 times.
# MIP Presolve eliminated 604 rows and 104 columns.
# Aggregator did 88 substitutions.
# Reduced MIP has 2814 rows, 1680 columns, and 10540 nonzeros.
# Reduced MIP has 240 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (5.56 ticks)
# Probing time = 0.00 sec. (0.41 ticks)
# Tried aggregator 1 time.
# Reduced MIP has 2814 rows, 1680 columns, and 10540 nonzeros.
# Reduced MIP has 240 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (7.26 ticks)
# Probing time = 0.00 sec. (0.41 ticks)
# Clique table members: 120.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 8 threads.
# Root relaxation solution time = 0.21 sec. (207.00 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                         5228.7562    -6088.4347           216.44%
#       0     0     1630.7439   113     5228.7562     1630.7439       31   68.81%
# *     0+    0                         1964.1345     1630.7439            16.97%
#       0     0     1631.4838   131     1964.1345      Cuts: 23      142   16.94%
# *     0+    0                         1809.9329     1631.4838             9.86%
#       0     0     1634.8833   114     1809.9329      Cuts: 37      308    9.67%
# *     0+    0                         1740.4679     1634.8833             6.07%
#       0     0     1635.0644   137     1740.4679      Cuts: 22      346    6.06%
#       0     0     1635.0665   134     1740.4679      Cuts: 23      355    6.06%
# *     0+    0                         1718.0684     1635.0665             4.83%
#       0     0     1635.0779   131     1718.0684       Cuts: 3      357    4.82%
# *     0+    0                         1712.3642     1635.2484             4.50%
#       0     2     1635.0779   131     1712.3642     1643.1360      357    4.04%
# Elapsed time = 1.14 sec. (844.30 ticks, tree = 0.01 MB, solutions = 6)
# *     7+    2                         1700.7720     1643.1360             3.39%
# *    68+   34                         1695.5106     1643.1360             3.09%
# *   104+   59                         1692.0017     1643.1360             2.89%
# *   112+   58                         1687.1373     1643.1360             2.61%
# *   138    67      integral     0     1686.6634     1643.1360    11311    2.58%
#     154    69     1644.1756   127     1686.6634     1644.2262    12010    2.52%
# *   354+  116                         1685.5303     1644.2658             2.45%
#     438   191     1672.1125    70     1685.5303     1650.9800    33828    2.05%
# *   471   212      integral     0     1685.3080     1650.9800    36558    2.04%
# *   673   277      integral     0     1684.4044     1664.8281    50356    1.16%
# *   959+  303                         1683.6349     1669.6697             0.83%
#    1051   340     1677.7133    45     1683.6349     1670.0986    67825    0.80%
# *  1159+  324                         1680.3604     1670.1980             0.60%
# *  1275   336      integral     0     1680.1235     1671.8126    79529    0.49%
# *  1403   283      integral     0     1679.8865     1672.7321    86812    0.43%
#    2102   176        cutoff           1679.8865     1677.7519   110799    0.13%
#
# Cover cuts applied:  129
# Flow cuts applied:  8
# Mixed integer rounding cuts applied:  14
# Zero-half cuts applied:  14
# Lift and project cuts applied:  1
# Gomory fractional cuts applied:  4
#
# Root node processing (before b&c):
#   Real time             =    1.13 sec. (842.46 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    2.51 sec. (1510.17 ticks)
#   Sync time (average)   =    0.55 sec.
#   Wait time (average)   =    0.02 sec.
#                           ------------
# Total (root+branch&cut) =    3.64 sec. (2352.63 ticks)
# Done!
# Time elapsed: 3.72035503387
#
# ~~~
# Done with 1400!
# ~~~
#
# Solving...
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 2 times.
# MIP Presolve eliminated 1928 rows and 292 columns.
# MIP Presolve modified 752 coefficients.
# Aggregator did 116 substitutions.
# Reduced MIP has 3506 rows, 1872 columns, and 12248 nonzeros.
# Reduced MIP has 240 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.02 sec. (12.64 ticks)
# Found incumbent of value 5408.980823 after 0.03 sec. (26.41 ticks)
# Probing fixed 0 vars, tightened 140 bounds.
# Probing time = 0.00 sec. (0.61 ticks)
# Tried aggregator 2 times.
# MIP Presolve eliminated 604 rows and 104 columns.
# Aggregator did 88 substitutions.
# Reduced MIP has 2814 rows, 1680 columns, and 10540 nonzeros.
# Reduced MIP has 240 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (5.56 ticks)
# Probing time = 0.00 sec. (0.41 ticks)
# Tried aggregator 1 time.
# Reduced MIP has 2814 rows, 1680 columns, and 10540 nonzeros.
# Reduced MIP has 240 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (7.26 ticks)
# Probing time = 0.00 sec. (0.41 ticks)
# Clique table members: 120.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 8 threads.
# Root relaxation solution time = 0.17 sec. (190.40 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                         5408.9808    -6077.7872           212.36%
#       0     0     1812.7514   112     5408.9808     1812.7514       27   66.49%
# *     0+    0                         2160.7583     1812.7514            16.11%
#       0     0     1814.0668    90     2160.7583      Cuts: 22      102   16.04%
# *     0+    0                         2074.7513     1814.0668            12.56%
#       0     0     1814.9816   120     2074.7513      Cuts: 35      338   12.52%
# *     0+    0                         2060.7102     1814.9816            11.92%
# *     0+    0                         1925.3297     1814.9816             5.73%
#       0     0     1815.1311   115     1925.3297      Cuts: 31      406    5.48%
#       0     0     1819.6899   111     1925.3297      Cuts: 19      572    5.48%
#       0     0     1819.7062   116     1925.3297      Cuts: 13      583    5.48%
# *     0+    0                         1881.5234     1819.7715             3.28%
#       0     0     1819.7294   104     1881.5234       Cuts: 3      590    3.21%
#       0     0     1823.7224   130     1881.5234      Cuts: 16      782    3.07%
#       0     0     1823.8412   128     1881.5234      Cuts: 40      811    3.07%
#       0     2     1823.8412   111     1881.5234     1828.6164      811    2.81%
# Elapsed time = 1.11 sec. (829.55 ticks, tree = 0.01 MB, solutions = 6)
# *    44+   21                         1880.7662     1828.6164             2.77%
# *    63+   21                         1870.7167     1828.6164             2.25%
#     205    92     1867.6305    49     1870.7167     1829.0633    16479    2.23%
# *   261+  131                         1869.5505     1831.1212             2.06%
# ...
# Aggregator did 116 substitutions.
# Reduced MIP has 3506 rows, 1872 columns, and 12248 nonzeros.
# Reduced MIP has 240 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.02 sec. (12.64 ticks)
# Found incumbent of value 6125.562781 after 0.03 sec. (26.41 ticks)
# Probing fixed 0 vars, tightened 140 bounds.
# Probing time = 0.00 sec. (0.61 ticks)
# Tried aggregator 2 times.
# MIP Presolve eliminated 604 rows and 104 columns.
# Aggregator did 88 substitutions.
# Reduced MIP has 2814 rows, 1680 columns, and 10540 nonzeros.
# Reduced MIP has 240 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (5.56 ticks)
# Probing time = 0.00 sec. (0.41 ticks)
# Tried aggregator 1 time.
# Reduced MIP has 2814 rows, 1680 columns, and 10540 nonzeros.
# Reduced MIP has 240 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (7.26 ticks)
# Probing time = 0.00 sec. (0.41 ticks)
# Clique table members: 120.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 8 threads.
# Root relaxation solution time = 0.20 sec. (197.54 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                         6125.5628    -6035.5320           198.53%
#       0     0     2536.4219    96     6125.5628     2536.4219       32   58.59%
# *     0+    0                         2862.2085     2536.4219            11.38%
# *     0+    0                         2716.3725     2536.4219             6.62%
#       0     0     2536.7649   114     2716.3725      Cuts: 17      157    6.54%
#       0     0     2540.4717   117     2716.3725      Cuts: 28      379    6.48%
#       0     0     2540.6126   122     2716.3725      Cuts: 45      411    6.47%
# *     0+    0                         2708.9407     2540.6126             6.21%
# *     0+    0                         2629.7498     2540.6126             3.39%
#       0     0     2540.6152   128     2629.7498       Cuts: 4      423    3.31%
#       0     0     2540.6171   118     2629.7498   Flowcuts: 1      426    3.31%
#       0     0     2540.6214   118     2629.7498      Cuts: 19      440    3.31%
# *     0+    0                         2610.6466     2542.6835             2.60%
# *     0+    0                         2605.6759     2546.6770             2.26%
#       0     2     2540.6214   114     2605.6759     2546.6770      440    2.26%
# Elapsed time = 1.08 sec. (743.87 ticks, tree = 0.01 MB, solutions = 7)
# *   192+   64                         2593.4404     2555.9691             1.44%
#     220    87     2571.0298    86     2593.4404     2555.9691    14564    1.44%
# *   304+   74                         2585.8059     2564.3364             0.83%
#     538   130        cutoff           2585.8059     2568.4930    35063    0.67%
#     989   216     2584.8097    30     2585.8059     2576.7943    55086    0.35%
# *  1112   240      integral     0     2585.7433     2578.4059    60340    0.28%
# *  1304   262      integral     0     2585.5693     2579.7958    66213    0.22%
# *  1480   265      integral     0     2585.2702     2580.6909    74790    0.18%
#
# Cover cuts applied:  119
# Flow cuts applied:  9
# Mixed integer rounding cuts applied:  15
# Zero-half cuts applied:  5
# Lift and project cuts applied:  4
# Gomory fractional cuts applied:  8
#
# Root node processing (before b&c):
#   Real time             =    1.08 sec. (741.87 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    2.02 sec. (1161.21 ticks)
#   Sync time (average)   =    0.45 sec.
#   Wait time (average)   =    0.01 sec.
#                           ------------
# Total (root+branch&cut) =    3.09 sec. (1903.08 ticks)
# Done!
# Time elapsed: 3.19113898277
#
# ~~~
# Done with 1650!
# ~~~
#
# Solving...
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 2 times.
# MIP Presolve eliminated 1928 rows and 292 columns.
# MIP Presolve modified 752 coefficients.
# Aggregator did 116 substitutions.
# Reduced MIP has 3506 rows, 1872 columns, and 12248 nonzeros.
# Reduced MIP has 240 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.02 sec. (12.64 ticks)
# Found incumbent of value 6303.636859 after 0.03 sec. (26.41 ticks)
# Probing fixed 0 vars, tightened 140 bounds.
# Probing time = 0.00 sec. (0.61 ticks)
# Tried aggregator 2 times.
# MIP Presolve eliminated 604 rows and 104 columns.
# Aggregator did 88 substitutions.
# Reduced MIP has 2814 rows, 1680 columns, and 10540 nonzeros.
# Reduced MIP has 240 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (5.56 ticks)
# Probing time = 0.00 sec. (0.41 ticks)
# Tried aggregator 1 time.
# Reduced MIP has 2814 rows, 1680 columns, and 10540 nonzeros.
# Reduced MIP has 240 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (7.26 ticks)
# Probing time = 0.00 sec. (0.41 ticks)
# Clique table members: 120.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 8 threads.
# Root relaxation solution time = 0.23 sec. (189.78 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                         6303.6369    -6025.0513           195.58%
#       0     0     2716.2575   109     6303.6369     2716.2575       28   56.91%
# *     0+    0                         2911.8700     2716.2575             6.72%
#       0     0     2717.3975   132     2911.8700      Cuts: 12      160    6.65%
#       0     0     2720.8341   117     2911.8700      Cuts: 63      326    6.56%
#       0     0     2720.9682   143     2911.8700      Cuts: 18      407    6.56%
# *     0+    0                         2886.9032     2720.9682             5.75%
#       0     0     2720.9756   148     2886.9032      Cuts: 19      422    5.75%
#       0     0     2720.9756   126     2886.9032       Cuts: 4      428    5.75%
# *     0+    0                         2800.8537     2720.9756             2.85%
#       0     0     2720.9756   118     2800.8537      Cuts: 22      444    2.85%
#       0     0     2723.2689   124     2800.8537       Cuts: 8      597    2.77%
#       0     0     2724.0102   127     2800.8537      Cuts: 37      718    2.74%
#       0     0     2724.1479   123     2800.8537      Cuts: 24      749    2.74%
# *     0+    0                         2789.4905     2724.1479             2.34%
#       0     2     2724.1479   102     2789.4905     2724.8418      749    2.32%
# Elapsed time = 1.27 sec. (851.99 ticks, tree = 0.01 MB, solutions = 5)
# *   157+   42                         2787.5227     2728.9475             2.10%
#     230    96     2787.1399    34     2787.5227     2732.8603     9034    1.96%
# *   257+   81                         2775.7064     2732.8603             1.54%
# *   331+  115                         2775.5627     2735.6827             1.44%
# *   354+  108                         2771.0639     2735.6827             1.28%
# *   373+  108                         2770.8158     2735.6827             1.27%
#     499   137        cutoff           2770.8158     2739.8575    20988    1.12%
# *   501+  103                         2768.2117     2739.8575             1.02%
# *   787+  206                         2767.3770     2748.2490             0.69%
# *   817+  193                         2765.8193     2748.6986             0.62%
#     924   212        cutoff           2765.8193     2754.3578    32719    0.41%
# *  1105   236      integral     0     2765.5828     2756.0025    35907    0.35%
# *  1177+  250                         2765.5204     2756.6157             0.32%
# *  1198+  249                         2765.3463     2756.6157             0.32%
# *  1201   257      integral     0     2765.3463     2756.6157    41595    0.32%
# *  1567   272      integral     0     2765.0473     2760.3495    53002    0.17%
#
# Cover cuts applied:  107
# Flow cuts applied:  12
# Mixed integer rounding cuts applied:  26
# Zero-half cuts applied:  17
# Lift and project cuts applied:  2
# Gomory fractional cuts applied:  8
#
# Root node processing (before b&c):
#   Real time             =    1.27 sec. (850.10 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    2.16 sec. (1243.14 ticks)
#   Sync time (average)   =    0.66 sec.
#   Wait time (average)   =    0.02 sec.
#                           ------------
# Total (root+branch&cut) =    3.43 sec. (2093.24 ticks)
# Done!
# Time elapsed: 3.51547789574
#
# ~~~
# Done with 1700!
# ~~~
#
# Solving...
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 2 times.
# MIP Presolve eliminated 1928 rows and 292 columns.
# MIP Presolve modified 752 coefficients.
# Aggregator did 116 substitutions.
# Reduced MIP has 3506 rows, 1872 columns, and 12248 nonzeros.
# Reduced MIP has 240 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.02 sec. (12.64 ticks)
# Found incumbent of value 6481.285444 after 0.03 sec. (26.41 ticks)
# Probing fixed 0 vars, tightened 140 bounds.
# Probing time = 0.00 sec. (0.61 ticks)
# Tried aggregator 2 times.
# MIP Presolve eliminated 604 rows and 104 columns.
# Aggregator did 88 substitutions.
# Reduced MIP has 2814 rows, 1680 columns, and 10540 nonzeros.
# Reduced MIP has 240 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (5.56 ticks)
# Probing time = 0.00 sec. (0.41 ticks)
# Tried aggregator 1 time.
# Reduced MIP has 2814 rows, 1680 columns, and 10540 nonzeros.
# Reduced MIP has 240 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (7.26 ticks)
# Probing time = 0.00 sec. (0.41 ticks)
# Clique table members: 120.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 8 threads.
# Root relaxation solution time = 0.18 sec. (182.65 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                         6481.2854    -6014.6037           192.80%
#       0     0     2895.6634   104     6481.2854     2895.6634       24   55.32%
# *     0+    0                         3282.3265     2895.6634            11.78%
# *     0+    0                         3190.8861     2895.6634             9.25%
#       0     0     2895.8161   125     3190.8861      Cuts: 27      109    9.19%
# *     0+    0                         2961.8771     2897.7050             2.17%
#       0     0     2897.4248    95     2961.8771      Cuts: 24      234    2.04%
#       0     0     2904.6246   113     2961.8771      Cuts: 23      370    1.93%
#       0     0     2904.6277   113     2961.8771      Cuts: 21      384    1.93%
#       0     2     2904.6277   105     2961.8771     2905.6235      384    1.90%
# Elapsed time = 0.97 sec. (730.62 ticks, tree = 0.01 MB, solutions = 4)
# *   100+   67                         2958.4649     2912.7538             1.55%
# *   106+   46                         2952.9945     2912.7538             1.36%
#     264   127     2938.7118    96     2952.9945     2915.3601    12308    1.27%
# *   275+  121                         2946.5107     2915.3601             1.06%
#     628   176     2942.6415    57     2946.5107     2933.6511    22933    0.44%
# *   757+  229                         2946.0378     2934.5443             0.39%
# *   809+  275                         2944.9926     2935.3996             0.33%
# *   859+  291                         2944.8678     2935.7527             0.31%
# *   899   275      integral     0     2944.3950     2935.9734    34090    0.29%
#    1383   247     2943.4592    16     2944.3950     2940.0396    48472    0.15%
#    1771    80        cutoff           2944.3950     2942.7220    59088    0.06%
#
# Cover cuts applied:  114
# Flow cuts applied:  8
# Mixed integer rounding cuts applied:  11
# Zero-half cuts applied:  8
# Gomory fractional cuts applied:  5
#
# Root node processing (before b&c):
#   Real time             =    0.94 sec. (728.59 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    1.95 sec. (1204.24 ticks)
#   Sync time (average)   =    0.53 sec.
#   Wait time (average)   =    0.01 sec.
#                           ------------
# Total (root+branch&cut) =    2.89 sec. (1932.83 ticks)
# Done!
# Time elapsed: 3.00587391853
#
# ~~~
# Done with 1750!
# ~~~
#
# Solving...
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 2 times.
# MIP Presolve eliminated 2052 rows and 412 columns.
# MIP Presolve modified 752 coefficients.
# Aggregator did 108 substitutions.
# Reduced MIP has 3390 rows, 1760 columns, and 11904 nonzeros.
# Reduced MIP has 240 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.02 sec. (11.93 ticks)
# Found incumbent of value 6658.510060 after 0.03 sec. (25.08 ticks)
# Probing fixed 0 vars, tightened 136 bounds.
# Probing time = 0.00 sec. (0.61 ticks)
# Tried aggregator 2 times.
# MIP Presolve eliminated 604 rows and 104 columns.
# Aggregator did 88 substitutions.
# Reduced MIP has 2698 rows, 1568 columns, and 10196 nonzeros.
# Reduced MIP has 240 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (6.11 ticks)
# Probing time = 0.00 sec. (0.41 ticks)
# Tried aggregator 1 time.
# Reduced MIP has 2698 rows, 1568 columns, and 10196 nonzeros.
# Reduced MIP has 240 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (6.94 ticks)
# Probing time = 0.00 sec. (0.41 ticks)
# Clique table members: 120.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 8 threads.
# Root relaxation solution time = 0.17 sec. (190.65 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                         6658.5101    -6004.1889           190.17%
#       0     0     3074.6411   113     6658.5101     3074.6411       28   53.82%
# *     0+    0                         3379.4401     3074.6411             9.02%
#       0     0     3074.9530   140     3379.4401      Cuts: 19      157    8.96%
#       0     0     3078.2826   129     3379.4401      Cuts: 49      263    8.91%
# *     0+    0                         3281.5178     3078.2826             6.19%
#       0     0     3078.2949   128     3281.5178      Cuts: 23      288    6.19%
# *     0+    0                         3148.8024     3078.2949             2.24%
#       0     0     3078.3107   116     3148.8024      Cuts: 11      297    2.24%
#       0     2     3078.3107   116     3148.8024     3079.6794      297    2.20%
# Elapsed time = 0.94 sec. (674.81 ticks, tree = 0.01 MB, solutions = 4)
# *   208+  140                         3146.8045     3094.1742             1.67%
#     209   120     3123.8954    55     3146.8045     3094.1742    12390    1.67%
# *   213   138      integral     0     3146.2947     3094.1742    13726    1.66%
# *   217+  130                         3135.8731     3094.1742             1.33%
# *   317+  116                         3133.3654     3100.7447             1.04%
# *   344+  114                         3124.0859     3100.7447             0.75%
# *   440+  124                         3123.7873     3101.9819             0.70%
# *   455   134      integral     0     3123.5509     3101.9819    24797    0.69%
#     836   187     3119.4090    67     3123.5509     3113.3879    34035    0.33%
# *  1097+  237                         3123.3146     3116.5441             0.22%
#    1252   221        cutoff           3123.3146     3117.9719    50125    0.17%
#    1758    47        cutoff           3123.3146     3122.4300    62182    0.03%
#
# Cover cuts applied:  115
# Flow cuts applied:  17
# Mixed integer rounding cuts applied:  8
# Zero-half cuts applied:  20
# Gomory fractional cuts applied:  3
#
# Root node processing (before b&c):
#   Real time             =    0.86 sec. (672.87 ticks)
# Parallel b&c, 8 threads:
#   Real time             =    2.44 sec. (1232.05 ticks)
#   Sync time (average)   =    0.98 sec.
#   Wait time (average)   =    0.01 sec.
#                           ------------
# Total (root+branch&cut) =    3.30 sec. (1904.92 ticks)
# Done!
# Time elapsed: 3.38729095459
#
# ~~~
# Done with 1800!
# ~~~

# %% [markdown]
# ## 3. Checking the effect of alpha on the traffic demand curve

# %%
_alphas = [x / 8.0 for x in range(4)]
_alphas2 = [x / 8.0 for x in range(4,8)]
_demands = [x for x in range(450, 1801, 50)]
_flow_weight = 0.6

_df_tuples = []
# (demand, runtime, delay, throughput, alpha, flow_weight)

for _a in _alphas2:
    for _d in _demands:
        dfx, dfy, dfg, dfparams, obj_values, runtime = run_model(demand=_d, alpha=_a, use=True, flow_weight=_flow_weight, log_output=False)
        generate_graphs(None, None, dfg, dfparams.capacity[(3,0,1)], dfparams.max_flow[(3,0,1)], _d, _a, _flow_weight, folder='')
        
        _df_tuples.append((_d, runtime, obj_values[0], obj_values[1], _a, _flow_weight))
        
        print("\n~~~\nDone with demand {}, alpha {}!\n~~~\n".format(_d, _a))
# Out:
# Solving...
# Done!
# Time elapsed: 159.514794111
#
# ~~~
# Done with demand 450, alpha 0.5!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 73.3284778595
#
# ~~~
# Done with demand 500, alpha 0.5!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 41.8842031956
#
# ~~~
# Done with demand 550, alpha 0.5!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 12.2617340088
#
# ~~~
# Done with demand 600, alpha 0.5!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 37.1376481056
#
# ~~~
# Done with demand 650, alpha 0.5!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 10.9574401379
#
# ~~~
# Done with demand 700, alpha 0.5!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 6.2417178154
#
# ~~~
# Done with demand 750, alpha 0.5!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 7.54641699791
#
# ~~~
# Done with demand 800, alpha 0.5!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 5.51469397545
#
# ~~~
# Done with demand 850, alpha 0.5!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 4.80589318275
#
# ~~~
# Done with demand 900, alpha 0.5!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 5.39438891411
#
# ~~~
# Done with demand 950, alpha 0.5!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 6.63487792015
#
# ~~~
# Done with demand 1000, alpha 0.5!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 6.31770896912
#
# ~~~
# Done with demand 1050, alpha 0.5!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.74517583847
#
# ~~~
# Done with demand 1100, alpha 0.5!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 5.52757287025
#
# ~~~
# Done with demand 1150, alpha 0.5!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 4.97739219666
#
# ~~~
# Done with demand 1200, alpha 0.5!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 4.39204502106
#
# ~~~
# Done with demand 1250, alpha 0.5!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 5.43984699249
#
# ~~~
# Done with demand 1300, alpha 0.5!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 4.49709296227
#
# ~~~
# Done with demand 1350, alpha 0.5!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 4.06677412987
#
# ~~~
# Done with demand 1400, alpha 0.5!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.4976708889
#
# ~~~
# Done with demand 1450, alpha 0.5!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 4.01753497124
#
# ~~~
# Done with demand 1500, alpha 0.5!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 4.15172100067
#
# ~~~
# Done with demand 1550, alpha 0.5!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.17715597153
#
# ~~~
# Done with demand 1600, alpha 0.5!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.9425330162
#
# ~~~
# Done with demand 1650, alpha 0.5!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.98308706284
#
# ~~~
# Done with demand 1700, alpha 0.5!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.31833696365
#
# ~~~
# Done with demand 1750, alpha 0.5!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.47572398186
#
# ~~~
# Done with demand 1800, alpha 0.5!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 109.746103048
#
# ~~~
# Done with demand 450, alpha 0.625!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 73.4154589176
#
# ~~~
# Done with demand 500, alpha 0.625!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 42.5459289551
#
# ~~~
# Done with demand 550, alpha 0.625!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 13.9139258862
#
# ~~~
# Done with demand 600, alpha 0.625!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 36.0411839485
#
# ~~~
# Done with demand 650, alpha 0.625!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 27.2725548744
#
# ~~~
# Done with demand 700, alpha 0.625!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 6.54295992851
#
# ~~~
# Done with demand 750, alpha 0.625!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 8.26960802078
#
# ~~~
# Done with demand 800, alpha 0.625!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 4.33073115349
#
# ~~~
# Done with demand 850, alpha 0.625!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 5.8902130127
#
# ~~~
# Done with demand 900, alpha 0.625!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 5.78872799873
#
# ~~~
# Done with demand 950, alpha 0.625!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 5.04591798782
#
# ~~~
# Done with demand 1000, alpha 0.625!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 9.07708692551
#
# ~~~
# Done with demand 1050, alpha 0.625!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 4.36752414703
#
# ~~~
# Done with demand 1100, alpha 0.625!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 4.81845021248
#
# ~~~
# Done with demand 1150, alpha 0.625!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 5.71507620811
#
# ~~~
# Done with demand 1200, alpha 0.625!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 5.5997209549
#
# ~~~
# Done with demand 1250, alpha 0.625!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 4.13062000275
#
# ~~~
# Done with demand 1300, alpha 0.625!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.4725060463
#
# ~~~
# Done with demand 1350, alpha 0.625!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.56713604927
#
# ~~~
# Done with demand 1400, alpha 0.625!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 4.05240607262
#
# ~~~
# Done with demand 1450, alpha 0.625!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 4.25720095634
#
# ~~~
# Done with demand 1500, alpha 0.625!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 2.72385120392
#
# ~~~
# Done with demand 1550, alpha 0.625!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.06493806839
#
# ~~~
# Done with demand 1600, alpha 0.625!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 2.58104276657
#
# ~~~
# Done with demand 1650, alpha 0.625!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 2.89828586578
#
# ~~~
# Done with demand 1700, alpha 0.625!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.44566702843
#
# ~~~
# Done with demand 1750, alpha 0.625!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 4.09646201134
#
# ~~~
# Done with demand 1800, alpha 0.625!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 184.163017035
#
# ~~~
# Done with demand 450, alpha 0.75!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 65.8590710163
#
# ~~~
# Done with demand 500, alpha 0.75!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 60.4520020485
#
# ~~~
# Done with demand 550, alpha 0.75!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 31.6038749218
#
# ~~~
# Done with demand 600, alpha 0.75!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 34.2657551765
#
# ~~~
# Done with demand 650, alpha 0.75!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 8.3396217823
#
# ~~~
# Done with demand 700, alpha 0.75!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 5.0173060894
#
# ~~~
# Done with demand 750, alpha 0.75!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 9.33526015282
#
# ~~~
# Done with demand 800, alpha 0.75!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 5.0190680027
#
# ~~~
# Done with demand 850, alpha 0.75!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 6.08458900452
#
# ~~~
# Done with demand 900, alpha 0.75!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 4.91674208641
#
# ~~~
# Done with demand 950, alpha 0.75!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 4.77965497971
#
# ~~~
# Done with demand 1000, alpha 0.75!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 6.95569705963
#
# ~~~
# Done with demand 1050, alpha 0.75!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 4.5173869133
#
# ~~~
# Done with demand 1100, alpha 0.75!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 4.17039704323
#
# ~~~
# Done with demand 1150, alpha 0.75!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 4.00019788742
#
# ~~~
# Done with demand 1200, alpha 0.75!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 5.64888596535
#
# ~~~
# Done with demand 1250, alpha 0.75!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 4.82457280159
#
# ~~~
# Done with demand 1300, alpha 0.75!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.72238993645
#
# ~~~
# Done with demand 1350, alpha 0.75!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.45568013191
#
# ~~~
# Done with demand 1400, alpha 0.75!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.38009309769
#
# ~~~
# Done with demand 1450, alpha 0.75!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.60780286789
#
# ~~~
# Done with demand 1500, alpha 0.75!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 4.98130512238
#
# ~~~
# Done with demand 1550, alpha 0.75!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.28112006187
#
# ~~~
# Done with demand 1600, alpha 0.75!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 2.44016599655
#
# ~~~
# Done with demand 1650, alpha 0.75!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.11213183403
#
# ~~~
# Done with demand 1700, alpha 0.75!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 2.68775701523
#
# ~~~
# Done with demand 1750, alpha 0.75!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 2.87144303322
#
# ~~~
# Done with demand 1800, alpha 0.75!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 100.597034931
#
# ~~~
# Done with demand 450, alpha 0.875!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 67.7621028423
#
# ~~~
# Done with demand 500, alpha 0.875!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 44.280944109
#
# ~~~
# Done with demand 550, alpha 0.875!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 48.4347829819
#
# ~~~
# Done with demand 600, alpha 0.875!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 30.0207839012
#
# ~~~
# Done with demand 650, alpha 0.875!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 31.1586568356
#
# ~~~
# Done with demand 700, alpha 0.875!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 7.72069191933
#
# ~~~
# Done with demand 750, alpha 0.875!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 6.97269105911
#
# ~~~
# Done with demand 800, alpha 0.875!
# ~~~
# Solving...
# Done!
# Time elapsed: 4.36917185783
#
# ~~~
# Done with demand 850, alpha 0.875!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 4.4025850296
#
# ~~~
# Done with demand 900, alpha 0.875!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.83675384521
#
# ~~~
# Done with demand 950, alpha 0.875!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 4.66839981079
#
# ~~~
# Done with demand 1000, alpha 0.875!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 6.46450901031
#
# ~~~
# Done with demand 1050, alpha 0.875!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 4.46837186813
#
# ~~~
# Done with demand 1100, alpha 0.875!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 5.74216103554
#
# ~~~
# Done with demand 1150, alpha 0.875!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 4.78553795815
#
# ~~~
# Done with demand 1200, alpha 0.875!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 4.83922719955
#
# ~~~
# Done with demand 1250, alpha 0.875!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 4.37526392937
#
# ~~~
# Done with demand 1300, alpha 0.875!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.7662858963
#
# ~~~
# Done with demand 1350, alpha 0.875!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 4.20653390884
#
# ~~~
# Done with demand 1400, alpha 0.875!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.78262591362
#
# ~~~
# Done with demand 1450, alpha 0.875!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.066010952
#
# ~~~
# Done with demand 1500, alpha 0.875!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 2.95181298256
#
# ~~~
# Done with demand 1550, alpha 0.875!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.34229302406
#
# ~~~
# Done with demand 1600, alpha 0.875!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.32357811928
#
# ~~~
# Done with demand 1650, alpha 0.875!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 2.83908295631
#
# ~~~
# Done with demand 1700, alpha 0.875!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.19761800766
#
# ~~~
# Done with demand 1750, alpha 0.875!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 4.14093089104
#
# ~~~
# Done with demand 1800, alpha 0.875!
# ~~~

# %% [markdown]
# ## Varying Alpha (Beta = 0) and Checking Delay and Throughput

# %%
def run_varying_alphas(demand=600, log_output=False):
    alphas = [x / 8.0 for x in range(9)]
    _df_tuples = []
    
    for a in alphas:
        dfx, dfy, dfg, dfparams, obj_values, runtime = run_model(demand=demand, alpha=a, use=False, flow_weight=0, log_output=log_output)
        _df_tuples.append((demand, runtime, obj_values[0], obj_values[1], a, 0))
        save_df(dfx, "volumes_d{}_a{}_b0".format(demand, a))
        save_df(dfy, "flows_d{}_a{}_b0".format(demand, a))
        save_df(dfg, "greentimes_d{}_a{}_b0".format(demand, a))
        print("\n~~~\nDone with demand {}, alpha {}!\n~~~\n".format(demand, a))
    
    df = pd.DataFrame(data=_df_tuples,columns=['demand', 'runtime', 'delay', 'throughput', 'alpha', 'flow_weight'])
    save_df(df, "results_vs_alpha_d{}_b0".format(demand))
    return df

# %%
for d in range(1450,1801,50):
    run_varying_alphas(d)
# Out:
# Solving...
# Done!
# Time elapsed: 0.888396978378
#
# ~~~
# Done with demand 1450, alpha 0.0!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 4.82988595963
#
# ~~~
# Done with demand 1450, alpha 0.125!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.76939988136
#
# ~~~
# Done with demand 1450, alpha 0.25!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 2.73412108421
#
# ~~~
# Done with demand 1450, alpha 0.375!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 2.97149801254
#
# ~~~
# Done with demand 1450, alpha 0.5!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.77615523338
#
# ~~~
# Done with demand 1450, alpha 0.625!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.26794600487
#
# ~~~
# Done with demand 1450, alpha 0.75!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 2.99579811096
#
# ~~~
# Done with demand 1450, alpha 0.875!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 2.88417196274
#
# ~~~
# Done with demand 1450, alpha 1.0!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 0.612238883972
#
# ~~~
# Done with demand 1500, alpha 0.0!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 4.24946713448
#
# ~~~
# Done with demand 1500, alpha 0.125!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 4.74412107468
#
# ~~~
# Done with demand 1500, alpha 0.25!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.79303407669
#
# ~~~
# Done with demand 1500, alpha 0.375!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 2.62351512909
#
# ~~~
# Done with demand 1500, alpha 0.5!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.84123110771
#
# ~~~
# Done with demand 1500, alpha 0.625!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 4.07449793816
#
# ~~~
# Done with demand 1500, alpha 0.75!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.38688707352
#
# ~~~
# Done with demand 1500, alpha 0.875!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 4.10013198853
#
# ~~~
# Done with demand 1500, alpha 1.0!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 0.847729206085
#
# ~~~
# Done with demand 1550, alpha 0.0!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 6.97335505486
#
# ~~~
# Done with demand 1550, alpha 0.125!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 4.38076305389
#
# ~~~
# Done with demand 1550, alpha 0.25!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.28594589233
#
# ~~~
# Done with demand 1550, alpha 0.375!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.46121096611
#
# ~~~
# Done with demand 1550, alpha 0.5!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.67665600777
#
# ~~~
# Done with demand 1550, alpha 0.625!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.97204899788
#
# ~~~
# Done with demand 1550, alpha 0.75!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.39310002327
#
# ~~~
# Done with demand 1550, alpha 0.875!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.75480103493
#
# ~~~
# Done with demand 1550, alpha 1.0!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 0.719836950302
#
# ~~~
# Done with demand 1600, alpha 0.0!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 5.11269593239
#
# ~~~
# Done with demand 1600, alpha 0.125!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 4.64608693123
#
# ~~~
# Done with demand 1600, alpha 0.25!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.94239091873
#
# ~~~
# Done with demand 1600, alpha 0.375!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.43899512291
#
# ~~~
# Done with demand 1600, alpha 0.5!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 4.62336397171
#
# ~~~
# Done with demand 1600, alpha 0.625!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 2.97258090973
#
# ~~~
# Done with demand 1600, alpha 0.75!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 4.02821493149
#
# ~~~
# Done with demand 1600, alpha 0.875!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.56160092354
#
# ~~~
# Done with demand 1600, alpha 1.0!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 0.877012968063
#
# ~~~
# Done with demand 1650, alpha 0.0!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 5.07308006287
#
# ~~~
# Done with demand 1650, alpha 0.125!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 5.09088206291
#
# ~~~
# Done with demand 1650, alpha 0.25!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 4.61391592026
#
# ~~~
# Done with demand 1650, alpha 0.375!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.8660569191
#
# ~~~
# Done with demand 1650, alpha 0.5!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.45374321938
#
# ~~~
# Done with demand 1650, alpha 0.625!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.31643795967
#
# ~~~
# Done with demand 1650, alpha 0.75!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.82076096535
#
# ~~~
# Done with demand 1650, alpha 0.875!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.2232811451
#
# ~~~
# Done with demand 1650, alpha 1.0!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 1.04355382919
#
# ~~~
# Done with demand 1700, alpha 0.0!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 5.81760787964
#
# ~~~
# Done with demand 1700, alpha 0.125!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 4.64661812782
#
# ~~~
# Done with demand 1700, alpha 0.25!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 4.60018181801
#
# ~~~
# Done with demand 1700, alpha 0.375!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.67522788048
#
# ~~~
# Done with demand 1700, alpha 0.5!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 2.77284598351
#
# ~~~
# Done with demand 1700, alpha 0.625!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.98528885841
#
# ~~~
# Done with demand 1700, alpha 0.75!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.03388881683
#
# ~~~
# Done with demand 1700, alpha 0.875!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.11673808098
#
# ~~~
# Done with demand 1700, alpha 1.0!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 1.18554210663
#
# ~~~
# Done with demand 1750, alpha 0.0!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 6.84052681923
#
# ~~~
# Done with demand 1750, alpha 0.125!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 4.23937106133
#
# ~~~
# Done with demand 1750, alpha 0.25!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 4.50963187218
#
# ~~~
# Done with demand 1750, alpha 0.375!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.50406384468
#
# ~~~
# Done with demand 1750, alpha 0.5!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.66800498962
#
# ~~~
# Done with demand 1750, alpha 0.625!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.56028413773
#
# ~~~
# Done with demand 1750, alpha 0.75!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.00058293343
#
# ~~~
# Done with demand 1750, alpha 0.875!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 4.14672803879
#
# ~~~
# Done with demand 1750, alpha 1.0!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 0.801415920258
#
# ~~~
# Done with demand 1800, alpha 0.0!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 5.29322290421
#
# ~~~
# Done with demand 1800, alpha 0.125!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 4.60164284706
#
# ~~~
# Done with demand 1800, alpha 0.25!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.53343605995
#
# ~~~
# Done with demand 1800, alpha 0.375!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 2.59208393097
#
# ~~~
# Done with demand 1800, alpha 0.5!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.12889289856
#
# ~~~
# Done with demand 1800, alpha 0.625!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 2.75412392616
#
# ~~~
# Done with demand 1800, alpha 0.75!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 2.95972394943
#
# ~~~
# Done with demand 1800, alpha 0.875!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 4.09208512306
#
# ~~~
# Done with demand 1800, alpha 1.0!
# ~~~

# %%
df_varying_alpha = pd.concat(dflist)
df_varying_alpha
# Out:
#     demand     runtime        delay  throughput  alpha  flow_weight
# 0      450    4.113032  1086.886076   44.556962  0.000            0
# 1      450   97.208230   861.240506   44.556962  0.125            0
# 2      450  113.829416   861.240506   44.556962  0.250            0
# 3      450  138.198439   861.240506   44.556962  0.375            0
# 4      450  149.478604   861.240506   44.556962  0.500            0
# 5      450  178.735804   861.240506   44.556962  0.625            0
# 6      450  156.508035   861.240506   44.556962  0.750            0
# 7      450  166.392350   861.240506   44.556962  0.875            0
# 8      450  118.227796   861.240506   44.556962  1.000            0
# 0      500    2.964355  1264.471871   44.556962  0.000            0
# 1      500   72.167541   999.557431   44.528833  0.125            0
# 2      500   80.497702   999.557431   44.528833  0.250            0
# 3      500   93.182296   995.503985   44.093296  0.375            0
# 4      500   77.003232   995.503985   44.093296  0.500            0
# 5      500   77.640432   995.503985   44.093296  0.625            0
# 6      500   61.054361   995.503985   44.093296  0.750            0
# 7      500   71.072589   995.503985   44.093296  0.875            0
# 8      500   56.855616   995.503985   44.093296  1.000            0
# 0      550    1.083762  1428.248945   44.556962  0.000            0
# 1      550   39.229089  1138.990155   44.491796  0.125            0
# 2      550   53.111832  1138.990155   44.491796  0.250            0
# 3      550   60.186374  1138.990155   44.491796  0.375            0
# 4      550   35.880058  1138.990155   44.491796  0.500            0
# 5      550   38.850896  1138.990155   44.491796  0.625            0
# 6      550   45.726800  1138.990155   44.491796  0.750            0
# 7      550   49.829074  1138.990155   44.491796  0.875            0
# 8      550   40.734581  1138.990155   44.491796  1.000            0
# 0      650    1.464251  1835.805907   44.556962  0.000            0
# 1      650   62.169763  1448.636193   44.380684  0.125            0
# 2      650   42.354477  1448.636193   44.380684  0.250            0
# ..     ...         ...          ...         ...    ...          ...
# 6      750    8.000096  1781.483826   44.556962  0.750            0
# 7      750    7.156120  1781.483826   44.556962  0.875            0
# 8      750    8.251348  1781.483826   44.556962  1.000            0
# 0      800    1.551616  2442.694562   44.556962  0.000            0
# 1      800    8.271998  1952.907626   44.556962  0.125            0
# 2      800    9.436009  1952.907642   44.556962  0.250            0
# 3      800    8.000633  1952.907622   44.556962  0.375            0
# 4      800    6.381176  1952.907625   44.556962  0.500            0
# 5      800    8.809542  1952.907642   44.556962  0.625            0
# 6      800    6.938231  1952.907642   44.556962  0.750            0
# 7      800    7.029703  1952.907642   44.556962  0.875            0
# 8      800    7.339800  1952.907642   44.556962  1.000            0
# 0      850    1.349335  2685.728317   44.556962  0.000            0
# 1      850    5.859330  2120.278012   44.556962  0.125            0
# 2      850    5.181032  2120.278012   44.556962  0.250            0
# 3      850    6.059742  2120.278012   44.556962  0.375            0
# 4      850    5.571885  2120.278012   44.556962  0.500            0
# 5      850    5.166421  2120.278012   44.556962  0.625            0
# 6      850    5.805489  2120.278012   44.556962  0.750            0
# 7      850    7.471531  2120.278012   44.556962  0.875            0
# 8      850    5.005763  2120.278012   44.556962  1.000            0
# 0      900    1.024897  2789.018987   44.556962  0.000            0
# 1      900    5.595113  2292.953586   44.556962  0.125            0
# 2      900    5.634595  2292.953586   44.556962  0.250            0
# 3      900    4.646273  2292.953586   44.556962  0.375            0
# 4      900    6.554811  2292.953586   44.556962  0.500            0
# 5      900    4.884776  2292.953571   44.556962  0.625            0
# 6      900    4.455863  2292.953586   44.556962  0.750            0
# 7      900    5.345917  2292.953576   44.556962  0.875            0
# 8      900    4.974226  2292.953586   44.556962  1.000            0
#
# [81 rows x 6 columns]

# %%
save_df(df_varying_alpha, "tmp_1")
