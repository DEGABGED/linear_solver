# %% [markdown]
# # CTM MILP Model Running Environment

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random
from pprint import pprint
import time

from ctmmodels.const import *
from ctmmodels.delaythroughput import DelayThroughputSimplex as ConflictModel
from ctmmodels.ringbarrier import DTSimplexRingBarrier as RBModel

# %%
IMAGE_PATH = 'graphs/'
DF_PATH = 'dataframes/'

# %% [markdown]
# **Notes on the models and parameters being used:**
#
# * 2 separate formulations were made: 1 dealing with individual movements in the intersection, and another dealing with phases in the stoplight. The latter has 33% less binary variables, and thus performed better in basic tests.
#
# * Saturation flow rate will be set to 600 vph instead of the 450 vph in the parent paper; this is so as to test both under and over saturated conditions.
#
# * Traffic will be distributed evenly between the 3 possible turns (left, through, and right). This is based on previous tests where left was getting essentially 0 green time.
#
# * Time range will be set to 60 seconds, or 30 time steps at 2 seconds per time step. Preliminary experiments show that 50 is the optimal cycle time for both delay and throughput (at demands ranging from 450 to 900 vph). *However*, previous tests on this model showed that no time was allotted to left turns when the cycle time was too small.

# %%
time_range = 30
time_ticks = np.arange(0, time_range+1, 1)

parameters = {
    'r_left': 1.0/3.0,
    'r_through': 1.0/3.0,
    'r_right': 1.0/3.0,
    'sat_flow_rate': 1800,
    'time_range': time_range,
    'time_step': 2,
    'g_min': 6,
    'g_max': 20
}

# Varying parameters: demand, use_flow_weight, flow_weight, alpha

# %%
def run_model(demand, alpha=1, beta=0, gamma=0, log_output=True, ringbarrier=False):
    if ringbarrier:
        model = RBModel(
            demand=demand,
            alpha=alpha,
            beta=beta,
            gamma=gamma,
            **parameters
        )
    else:
        model = ConflictModel(
            demand=demand,
            alpha=alpha,
            beta=beta,
            gamma=gamma,
            **parameters
        )
    model.generate()
    runtime = model.solve(log_output=log_output)
    dfx, dfy, dfg = model.return_solution()
    dfparams = model.return_parameters()
    obj_values = model.return_objective_value()
    return dfx, dfy, dfg, dfparams, obj_values, runtime

# %% [markdown]
# ## Intersection Cell Network

# %% [markdown]
# ![title](img/4leg-intersection.png)

# %% [markdown]
# ## Setting the path of cells to check

# %%
_approach = 0

_approach_terms = [
    'Left',
    'Through',
    'Right'
]

_cell_path = [
    (CELL_SOURCE,0,_approach),
    (CELL_NORMAL,0,_approach),
    (CELL_NORMAL,1,_approach),
    (CELL_NORMAL,2,_approach),
    (CELL_MOVEMENT,THROUGH_TURN,_approach),
    S_mapping((CELL_MOVEMENT,THROUGH_TURN,_approach))[0]
]

def movement_paths(approach):
    return [
        [
            (CELL_SOURCE,0,approach),
            (CELL_NORMAL,0,approach),
            (CELL_NORMAL,1,approach),
            (CELL_NORMAL,2,approach),
            (CELL_MOVEMENT,LEFT_TURN,approach),
            S_mapping((CELL_MOVEMENT,LEFT_TURN,approach))[0]
        ],
        [
            (CELL_SOURCE,0,approach),
            (CELL_NORMAL,0,approach),
            (CELL_NORMAL,1,approach),
            (CELL_NORMAL,2,approach),
            (CELL_MOVEMENT,THROUGH_TURN,approach),
            S_mapping((CELL_MOVEMENT,THROUGH_TURN,approach))[0]
        ],
        [
            (CELL_SOURCE,0,approach),
            (CELL_NORMAL,0,approach),
            (CELL_NORMAL,1,approach),
            (CELL_NORMAL,2,approach),
            (CELL_MOVEMENT,RIGHT_TURN,approach),
            S_mapping((CELL_MOVEMENT,RIGHT_TURN,approach))[0]
        ]
    ]

# %% [markdown]
# ## Comparing cell volumes

# %%
def plot_volume(dfx, cell_path, title, headless=True, filename='volume.png'):
    dfx_approach = pd.concat([
        dfx[dfx.cell == c].sort_values(by='timestep')
        for c in cell_path
    ]).pivot(index='timestep', columns='cell', values='volume')
    
    fig, axs = plt.subplots(1,2, figsize=(20,10))
    
    sns.lineplot(data=dfx_approach, ax=axs[0])
    sns.lineplot(data=dfx_approach.cumsum(), ax=axs[1])

    axs[0].set_title('Volume of cells')
    axs[0].set_xlabel('Timesteps')
    axs[0].set_ylabel('Instantaneous volume')
    axs[0].set_xticks(time_ticks, minor=True)

    axs[1].set_title('Volume of cells (cumulative)')
    axs[1].set_xlabel('Timesteps')
    axs[1].set_ylabel('Cumulative volume')
    axs[1].set_xticks(time_ticks, minor=True)
    
    fig.suptitle(title, fontsize=18)
    
    if headless:
        fig.savefig(IMAGE_PATH + filename)
        plt.close(fig)

# %% [markdown]
# ## Comparing flows

# %%
def plot_flow(dfy, cell_path, title, headless=True, filename='flow.png'):
    dfy_approach = pd.concat([
        dfy[dfy.cell_from == c].groupby(['cell_from', 'timestep']).agg({'flow': 'sum'}).sort_values(by='timestep')
        for c in cell_path
    ]).reset_index().pivot(index='timestep', columns='cell_from', values='flow')
    
    fig, axs = plt.subplots(1,2, figsize=(20,10))

    sns.lineplot(data=dfy_approach, ax=axs[0])
    sns.lineplot(data=dfy_approach.cumsum(), ax=axs[1])

    axs[0].set_title('Flow from cells')
    axs[0].set_xlabel('Timesteps')
    axs[0].set_ylabel('Instantaneous flow')
    axs[0].set_xticks(time_ticks, minor=True)

    axs[1].set_title('Flow from cells (cumulative)')
    axs[1].set_xlabel('Timesteps')
    axs[1].set_ylabel('Cumulative flow')
    axs[1].set_xticks(time_ticks, minor=True)
    
    fig.suptitle(title, fontsize=18)
    
    if headless:
        fig.savefig(IMAGE_PATH + filename)
        plt.close(fig)

# %% [markdown]
# ## Comparing specific green time

# %%
all_phases = [intToBinTuple(x) for x in range(8)]
all_phases_labels = [
    "Left, Westbound",
    "Through, Eastbound",
    "Left, Southbound",
    "Through, Southbound",
    "Left, Eastbound",
    "Through, Westbound",
    "Left, Northbound",
    "Through, Northbound",
]

def plot_greentime(dfg, title, headless=True, filename='greentime.png'):
    dfg_map = dfg.pivot(index='timestep', columns='cell', values='is_green')

    fig, axs = plt.subplots(8,1,figsize=(18,18), sharey=True)

    for ndx, t in enumerate(all_phases):
        sns.lineplot(data=dfg_map[t], ax=axs[ndx])
        axs[ndx].text(0.01,.5,all_phases_labels[ndx],
            horizontalalignment='left',
            transform=axs[ndx].transAxes,
            fontsize='large')
        axs[ndx].set_xticks(time_ticks, minor=False)
    
    fig.suptitle(title, fontsize=18)
    
    if headless:
        fig.savefig(IMAGE_PATH + filename)
        plt.close(fig)

# %% [markdown]
# ## Generating graphs for each model case

# %%
def generate_graphs(dfx, dfy, dfg, capacity, max_flow, demand, alpha, flow_weight, folder=''):
    cell_paths = movement_paths(_approach)
    
    for ndx, cellpath in enumerate(cell_paths):
        if dfx is not None:
            plot_volume(dfx,
                        cellpath,
                        '''Volume in cells at {} vph and {}% delay weight ({} turn)
                        (Cap: {:.2f}, Max Flow: {}, Flow Weight: {})'''
                            .format(demand, alpha*100, _approach_terms[ndx], capacity, max_flow, flow_weight),
                        filename=folder+'volumes/{}vph_{}alpha_{}flow_volume_{}.png'
                            .format(demand, alpha, flow_weight, _approach_terms[ndx].lower()))
        
        if dfy is not None:
            plot_flow(dfy,
                      cellpath,
                      '''Flow from cells at {} vph and {}% delay weight ({} turn)
                      (Cap: {:.2f}, Max Flow: {}, Flow Weight: {})'''
                          .format(demand, alpha*100, _approach_terms[ndx], capacity, max_flow, flow_weight),
                      filename=folder+'flows/{}vph_{}alpha_{}flow_flow_{}.png'
                          .format(demand, alpha, flow_weight, _approach_terms[ndx].lower()))
    
    if dfg is not None:
        plot_greentime(dfg,
                       '''Green times at {} vph and {}% delay weight
                       (Cap: {:.2f}, Max Flow: {}, Flow Weight: {})'''
                           .format(demand, alpha*100, capacity, max_flow, flow_weight),
                       filename=folder+'greentimes/{}vph_{}alpha_{}flow_greetime.png'
                           .format(demand, alpha, flow_weight))

# %%
def plot_obj_values(obj_values, title, xaxis, xlabel, headless=True, filename='obj.png'):
    fig, axs = plt.subplots(1,2,figsize=(20,10))

    axs[0].plot(xaxis, [x[0] for x in obj_values])
    axs[0].set_title("Computed total delay")
    axs[0].set_ylabel("Total vehicle delay (timesteps)")
    axs[0].set_xlabel(xlabel)

    axs[1].plot(xaxis, [x[1] for x in obj_values])
    axs[1].set_title("Computed total throughput")
    axs[1].set_ylabel("Total vehicle throughput (veh)")
    axs[1].set_xlabel(xlabel)
    
    fig.suptitle(title, fontsize=18)
    
    if headless:
        fig.savefig(IMAGE_PATH + filename)
        plt.close(fig)

# %% [markdown]
# ## Saving dataframes

# %%
def save_df(df, filename):
    df.to_pickle(DF_PATH + filename + ".pkl")

# %% [markdown]
# ## 1. Comparing Conflict and RB models

# %%
#c_dfx, c_dfy, c_dfg, c_dfparams, c_obj_values, c_runtime = run_model(demand=600, alpha=0.4, beta=0.4, gamma=0.2, log_output=True, ringbarrier=False)
rb_dfx, rb_dfy, rb_dfg, rb_dfparams, rb_obj_values, rb_runtime = run_model(demand=600, alpha=0.4, beta=0.4, gamma=0.2, log_output=True, ringbarrier=True)
# Out:
# Solving...
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 2 times.
# MIP Presolve eliminated 1520 rows and 292 columns.
# MIP Presolve modified 692 coefficients.
# Aggregator did 158 substitutions.
# Reduced MIP has 3444 rows, 1890 columns, and 11812 nonzeros.
# Reduced MIP has 270 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.02 sec. (12.64 ticks)
# Found incumbent of value 913.976488 after 0.04 sec. (22.91 ticks)
# Probing fixed 0 vars, tightened 132 bounds.
# Probing time = 0.02 sec. (0.61 ticks)
# Tried aggregator 2 times.
# MIP Presolve eliminated 604 rows and 104 columns.
# Aggregator did 88 substitutions.
# Reduced MIP has 2752 rows, 1698 columns, and 10104 nonzeros.
# Reduced MIP has 270 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.02 sec. (5.28 ticks)
# Probing time = 0.01 sec. (0.43 ticks)
# Tried aggregator 1 time.
# Reduced MIP has 2752 rows, 1698 columns, and 10104 nonzeros.
# Reduced MIP has 270 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (6.76 ticks)
# Probing time = 0.00 sec. (0.52 ticks)
# Clique table members: 540.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 4 threads.
# Root relaxation solution time = 0.15 sec. (129.96 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                          913.9765    -2515.1184           375.18%
#       0     0     -113.6563   151      913.9765     -113.6563        0  112.44%
# *     0+    0                           37.6605     -113.6563           401.79%
# *     0+    0                          -36.3325     -113.6563           212.82%
#       0     0     -108.0559   162      -36.3325     Cuts: 140      254  197.41%
# *     0+    0                          -38.5738     -108.0559           180.13%
#       0     0     -103.6187   174      -38.5738      Cuts: 69      520  168.62%
#       0     0     -100.9863   168      -38.5738     Cuts: 147      695  161.80%
#    7211  1561        cutoff            -55.1091      -65.0056   615851   17.96%
#    7596  1678      -56.2503    93      -55.1091      -65.0056   639728   17.96%
#    8031  1773      -59.6306   123      -55.1091      -65.0056   662727   17.96%
#    8496  1851      -59.6621   110      -55.1091      -64.3275   684133   16.73%
#    8936  1929      -55.5575   132      -55.1091      -63.5398   711482   15.30%
#    9345  1986        cutoff            -55.1091      -62.9594   732773   14.24%
# Elapsed time = 42.79 sec. (24802.08 ticks, tree = 14.79 MB, solutions = 10)
#    9779  1983        cutoff            -55.1091      -62.3915   759779   13.21%
#   10235  1973      -55.1981    59      -55.1091      -61.6243   779082   11.82%
#   10748  1930      -55.5646    62      -55.1091      -60.9492   808694   10.60%
#   11273  1881        cutoff            -55.1091      -60.1141   835672    9.08%
#   11761  1770        cutoff            -55.1091      -59.3539   857588    7.70%
#   12313  1598      -56.6709    77      -55.1091      -58.6534   882952    6.43%
#   12910  1310        cutoff            -55.1091      -57.9037   912632    5.07%
#   13771   876        cutoff            -55.1091      -56.8416   941490    3.14%
#
# GUB cover cuts applied:  15
# Clique cuts applied:  36
# Cover cuts applied:  88
# Implied bound cuts applied:  3
# Flow cuts applied:  45
# Mixed integer rounding cuts applied:  44
# Zero-half cuts applied:  11
# Lift and project cuts applied:  21
# Gomory fractional cuts applied:  31
#
# Root node processing (before b&c):
#   Real time             =    2.79 sec. (1363.14 ticks)
# Parallel b&c, 4 threads:
#   Real time             =   54.38 sec. (31848.80 ticks)
#   Sync time (average)   =    3.97 sec.
#   Wait time (average)   =    0.07 sec.
#                           ------------
# Total (root+branch&cut) =   57.17 sec. (33211.94 ticks)
# Done!
# Time elapsed: 57.2148799896

# %%
#print(c_obj_values)
print(rb_obj_values)
# Out:
# (1287.1040787623067, 44.30661040787621, -55.10911892245151)

# %%
plot_flow(rb_dfy, _cell_path, "Conflict Model (600 vphpl)", headless=False, filename='flow.png')

# %%
plot_greentime(rb_dfg, "Conflict Model (600 vphpl, 0.4/0.4/0.2)", headless=False)

# %% [markdown]
# ## 2. Plotting delay and throughput on the simplex

# %%
def generate_simplex(steps=10):
    simplex = [(a,b,steps-(a+b)) for a in range(steps+1) for b in range(steps - a + 1)]
    normalized = []
    for point in simplex:
        normalized.append((float(point[0]) / steps, float(point[1]) / steps, float(point[2]) / steps))
    return normalized

# %%
def run_on_simplex(demand=900, simplex_slice=[], log_output=False, folder='triple_simplex/', batchrun=1):
    _df_tuples = []
    
    for p in simplex_slice:
        a, b, c = p
        dfx, dfy, dfg, dfparams, obj_values, runtime = run_model(demand=demand, alpha=a, beta=b, gamma=c, log_output=log_output)
        _df_tuples.append((demand, runtime, obj_values[0], obj_values[1], obj_values[2], a, b, c))
        save_df(dfx, "{}volumes/volumes_d{}_a{}_b{}_c{}".format(folder, demand, a, b, c))
        save_df(dfy, "{}flows/flows_d{}_a{}_b{}_c{}".format(folder, demand, a, b, c))
        save_df(dfg, "{}greentimes/greentimes_d{}_a{}_b{}_c{}".format(folder, demand, a, b, c))
        print("\n~~~\nDone with demand {}, point ({}, {}, {})!\n~~~\n".format(demand, a, b, c))
    
    df = pd.DataFrame(data=_df_tuples,columns=['demand', 'runtime', 'delay', 'throughput', 'objective_value', 'alpha', 'beta', 'gamma'])
    save_df(df, "{}results_simplex_d{}_{}".format(folder, demand, batchrun))
    return df

# %%
_grid = generate_simplex()
_demands = [x for x in range(450,1801,50)]
_batchsize = 4

# %%
#print("~~~~ Demand = {} ~~~~".format(x))
run_on_simplex(1350, simplex_slice=_grid, batchrun=6)
# Out:
# Solving...
# Done!
# Time elapsed: 0.529932975769
#
# ~~~
# Done with demand 1350, point (0.0, 0.0, 1.0)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 0.274410963058
#
# ~~~
# Done with demand 1350, point (0.0, 0.1, 0.9)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 0.610217094421
#
# ~~~
# Done with demand 1350, point (0.0, 0.2, 0.8)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 0.92948102951
#
# ~~~
# Done with demand 1350, point (0.0, 0.3, 0.7)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 0.743527173996
#
# ~~~
# Done with demand 1350, point (0.0, 0.4, 0.6)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 0.946290969849
#
# ~~~
# Done with demand 1350, point (0.0, 0.5, 0.5)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 0.387392997742
#
# ~~~
# Done with demand 1350, point (0.0, 0.6, 0.4)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 0.503174066544
#
# ~~~
# Done with demand 1350, point (0.0, 0.7, 0.3)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 0.611775159836
#
# ~~~
# Done with demand 1350, point (0.0, 0.8, 0.2)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 0.755532979965
#
# ~~~
# Done with demand 1350, point (0.0, 0.9, 0.1)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 0.489289999008
#
# ~~~
# Done with demand 1350, point (0.0, 1.0, 0.0)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 2.76605200768
#
# ~~~
# Done with demand 1350, point (0.1, 0.0, 0.9)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.15622615814
#
# ~~~
# Done with demand 1350, point (0.1, 0.1, 0.8)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.66833376884
#
# ~~~
# Done with demand 1350, point (0.1, 0.2, 0.7)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 5.17224097252
#
# ~~~
# Done with demand 1350, point (0.1, 0.3, 0.6)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.81218004227
#
# ~~~
# Done with demand 1350, point (0.1, 0.4, 0.5)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 4.69155693054
#
# ~~~
# Done with demand 1350, point (0.1, 0.5, 0.4)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 4.50602483749
#
# ~~~
# Done with demand 1350, point (0.1, 0.6, 0.3)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 6.02524900436
#
# ~~~
# Done with demand 1350, point (0.1, 0.7, 0.2)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 5.34520697594
#
# ~~~
# Done with demand 1350, point (0.1, 0.8, 0.1)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 5.71693301201
#
# ~~~
# Done with demand 1350, point (0.1, 0.9, 0.0)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.38320803642
#
# ~~~
# Done with demand 1350, point (0.2, 0.0, 0.8)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.39764285088
#
# ~~~
# Done with demand 1350, point (0.2, 0.1, 0.7)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.77242708206
#
# ~~~
# Done with demand 1350, point (0.2, 0.2, 0.6)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.24639010429
#
# ~~~
# Done with demand 1350, point (0.2, 0.3, 0.5)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.4531648159
#
# ~~~
# Done with demand 1350, point (0.2, 0.4, 0.4)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 2.87548494339
#
# ~~~
# Done with demand 1350, point (0.2, 0.5, 0.3)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.37438702583
#
# ~~~
# Done with demand 1350, point (0.2, 0.6, 0.2)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 4.94306993484
#
# ~~~
# Done with demand 1350, point (0.2, 0.7, 0.1)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.92952823639
#
# ~~~
# Done with demand 1350, point (0.2, 0.8, 0.0)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 4.17304396629
#
# ~~~
# Done with demand 1350, point (0.3, 0.0, 0.7)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.24007511139
#
# ~~~
# Done with demand 1350, point (0.3, 0.1, 0.6)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.19738698006
#
# ~~~
# Done with demand 1350, point (0.3, 0.2, 0.5)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.53890180588
#
# ~~~
# Done with demand 1350, point (0.3, 0.3, 0.4)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.39927911758
#
# ~~~
# Done with demand 1350, point (0.3, 0.4, 0.3)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.36303305626
#
# ~~~
# Done with demand 1350, point (0.3, 0.5, 0.2)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.32442903519
#
# ~~~
# Done with demand 1350, point (0.3, 0.6, 0.1)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.81135106087
#
# ~~~
# Done with demand 1350, point (0.3, 0.7, 0.0)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.02416801453
#
# ~~~
# Done with demand 1350, point (0.4, 0.0, 0.6)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.49374008179
#
# ~~~
# Done with demand 1350, point (0.4, 0.1, 0.5)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 2.56013798714
#
# ~~~
# Done with demand 1350, point (0.4, 0.2, 0.4)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.37389111519
#
# ~~~
# Done with demand 1350, point (0.4, 0.3, 0.3)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.35488796234
#
# ~~~
# Done with demand 1350, point (0.4, 0.4, 0.2)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.57300806046
#
# ~~~
# Done with demand 1350, point (0.4, 0.5, 0.1)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.12241387367
#
# ~~~
# Done with demand 1350, point (0.4, 0.6, 0.0)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 2.70504283905
#
# ~~~
# Done with demand 1350, point (0.5, 0.0, 0.5)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.91184091568
#
# ~~~
# Done with demand 1350, point (0.5, 0.1, 0.4)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.53697919846
#
# ~~~
# Done with demand 1350, point (0.5, 0.2, 0.3)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 5.13271903992
#
# ~~~
# Done with demand 1350, point (0.5, 0.3, 0.2)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.81438708305
#
# ~~~
# Done with demand 1350, point (0.5, 0.4, 0.1)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 4.36078095436
#
# ~~~
# Done with demand 1350, point (0.5, 0.5, 0.0)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.10402488708
#
# ~~~
# Done with demand 1350, point (0.6, 0.0, 0.4)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.49885582924
#
# ~~~
# Done with demand 1350, point (0.6, 0.1, 0.3)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 4.59480500221
#
# ~~~
# Done with demand 1350, point (0.6, 0.2, 0.2)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 4.0576839447
#
# ~~~
# Done with demand 1350, point (0.6, 0.3, 0.1)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.60633707047
#
# ~~~
# Done with demand 1350, point (0.6, 0.4, 0.0)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 2.79240608215
#
# ~~~
# Done with demand 1350, point (0.7, 0.0, 0.3)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 2.47200393677
#
# ~~~
# Done with demand 1350, point (0.7, 0.1, 0.2)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 2.21201014519
#
# ~~~
# Done with demand 1350, point (0.7, 0.2, 0.1)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 2.87772417068
#
# ~~~
# Done with demand 1350, point (0.7, 0.3, 0.0)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 2.83250999451
#
# ~~~
# Done with demand 1350, point (0.8, 0.0, 0.2)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.23304319382
#
# ~~~
# Done with demand 1350, point (0.8, 0.1, 0.1)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 2.9710290432
#
# ~~~
# Done with demand 1350, point (0.8, 0.2, 0.0)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3.3404071331
#
# ~~~
# Done with demand 1350, point (0.9, 0.0, 0.1)!
# ~~~
#
# Solving...
# Done!
# Time elapsed: 3
# 47    1350  3.536979  3994.746835   44.417722       735.612290    0.5   0.2
# 48    1350  5.132719  3994.746835   44.417722      1071.740323    0.5   0.3
# 49    1350  3.814387  3994.746835   44.417722      1407.868356    0.5   0.4
# 50    1350  4.360781  3994.746835   44.417722      1743.996388    0.5   0.5
# 51    1350  3.104025  3994.746835   44.417722       781.512702    0.6   0.0
# 52    1350  3.498856  3994.746835   44.417722      1117.640735    0.6   0.1
# 53    1350  4.594805  3994.746835   44.417722      1453.768767    0.6   0.2
# 54    1350  4.057684  3994.746835   44.417722      1789.896800    0.6   0.3
# 55    1350  3.606337  3994.746835   44.417722      2126.024833    0.6   0.4
# 56    1350  2.792406  3994.746835   44.417722      1499.669179    0.7   0.0
# 57    1350  2.472004  3994.746835   44.417722      1835.797212    0.7   0.1
# 58    1350  2.212010  3994.746835   44.417722      2171.925244    0.7   0.2
# 59    1350  2.877724  3994.746835   44.417722      2508.053277    0.7   0.3
# 60    1350  2.832510  3994.746835   44.417722      2217.825656    0.8   0.0
# 61    1350  3.233043  3994.746835   44.417722      2553.953689    0.8   0.1
# 62    1350  2.971029  3994.746835   44.417722      2890.081722    0.8   0.2
# 63    1350  3.340407  3994.746835   44.417722      2935.982133    0.9   0.0
# 64    1350  3.651802  3994.746835   44.417722      3272.110166    0.9   0.1
# 65    1350  3.887607  3994.746835   44.417722      3654.138610    1.0   0.0
#
#     gamma
# 0     1.0
# 1     0.9
# 2     0.8
# 3     0.7
# 4     0.6
# 5     0.5
# 6     0.4
# 7     0.3
# 8     0.2
# 9     0.1
# 10    0.0
# 11    0.9
# 12    0.8
# 13    0.7
# 14    0.6
# 15    0.5
# 16    0.4
# 17    0.3
# 18    0.2
# 19    0.1
# 20    0.0
# 21    0.8
# 22    0.7
# 23    0.6
# 24    0.5
# 25    0.4
# 26    0.3
# 27    0.2
# 28    0.1
# 29    0.0
# ..    ...
# 36    0.1
# 37    0.0
# 38    0.6
# 39    0.5
# 40    0.4
# 41    0.3
# 42    0.2
# 43    0.1
# 44    0.0
# 45    0.5
# 46    0.4
# 47    0.3
# 48    0.2
# 49    0.1
# 50    0.0
# 51    0.4
# 52    0.3
# 53    0.2
# 54    0.1
# 55    0.0
# 56    0.3
# 57    0.2
# 58    0.1
# 59    0.0
# 60    0.2
# 61    0.1
# 62    0.0
# 63    0.1
# 64    0.0
# 65    0.0
#
# [66 rows x 8 columns]

# %%
df = pd.read_pickle(DF_PATH + "triple_simplex/results_simplex_d900_2.pkl")

# %%
df
# Out:
#     demand   runtime        delay  throughput  objective_value  alpha  beta  \
# 0      900  1.023374  2466.544304   42.556962     -3080.590717    0.0   0.0
# 1      900  0.985121  2412.025316   44.556962     -2789.198312    0.0   0.1
# 2      900  1.438595  2403.544304   44.556962     -2497.805907    0.0   0.2
# 3      900  0.467626  2427.166667   44.556962     -2206.413502    0.0   0.3
# 4      900  0.663082  2432.265823   44.556962     -1915.021097    0.0   0.4
# 5      900  0.862824  2451.291139   44.556962     -1623.628692    0.0   0.5
# 6      900  0.591435  2416.006329   44.556962     -1332.236287    0.0   0.6
# 55     900  4.916852  2292.953566   44.556962      1216.073898    0.6   0.4
# 56     900  4.278850  2292.953586   44.556962       572.353457    0.7   0.0
# 57     900  4.211913  2292.953586   44.556962       863.745862    0.7   0.1
# 58     900  4.298949  2292.953586   44.556962      1155.138267    0.7   0.2
# 59     900  5.227518  2292.953571   44.556962      1446.530662    0.7   0.3
# 60     900  6.852567  2292.953586   44.556962      1094.202625    0.8   0.0
# 61     900  4.896557  2292.953586   44.556962      1385.595030    0.8   0.1
# 62     900  4.109136  2292.953586   44.556962      1676.987435    0.8   0.2
# 63     900  5.253857  2292.953576   44.556962      1616.051784    0.9   0.0
# 64     900  5.472784  2292.953586   44.556962      1907.444197    0.9   0.1
# 65     900  4.112479  2292.953576   44.556962      2137.900950    1.0   0.0
#
#     gamma
# 0     1.0
# 1     0.9
# 2     0.8
# 3     0.7
# 4     0.6
# 5     0.5
# 6     0.4
# 7     0.3
# 8     0.2
# 9     0.1
# 10    0.0
# 11    0.9
# 12    0.8
# 13    0.7
# 14    0.6
# 15    0.5
# 16    0.4
# 17    0.3
# 18    0.2
# 19    0.1
# 20    0.0
# 21    0.8
# 22    0.7
# 23    0.6
# 24    0.5
# 25    0.4
# 26    0.3
# 27    0.2
# 28    0.1
# 29    0.0
# ..    ...
# 36    0.1
# 37    0.0
# 38    0.6
# 39    0.5
# 40    0.4
# 41    0.3
# 42    0.2
# 43    0.1
# 44    0.0
# 45    0.5
# 46    0.4
# 47    0.3
# 48    0.2
# 49    0.1
# 50    0.0
# 51    0.4
# 52    0.3
# 53    0.2
# 54    0.1
# 55    0.0
# 56    0.3
# 57    0.2
# 58    0.1
# 59    0.0
# 60    0.2
# 61    0.1
# 62    0.0
# 63    0.1
# 64    0.0
# 65    0.0
#
# [66 rows x 8 columns]

# %%
import ternary

# %%
df_nparr = df.values
delay_dict = {}
thru_dict = {}
runtime_dict = {}

for row in df_nparr:
    runtime_dict[(row[-3]*10, row[-2]*10, row[-1]*10)] = row[1]
    delay_dict[(row[-3]*10, row[-2]*10, row[-1]*10)] = row[2]
    thru_dict[(row[-3]*10, row[-2]*10, row[-1]*10)] = row[3]

# %%
scale = 10

figure, tax = ternary.figure(scale=10)
figure.set_size_inches(10, 8)
tax.heatmap(delay_dict, style="triangular")
tax.boundary(linewidth=2.0)
tax.set_title("Delay over Simplex of 3 parameters")
tax.ticks(axis='lbr', linewidth=1, multiple=5)
tax.clear_matplotlib_ticks()
tax.show()

# %%
scale = 10

figure, tax = ternary.figure(scale=10)
figure.set_size_inches(10, 8)
tax.heatmap(thru_dict, style="triangular")
tax.boundary(linewidth=2.0)
tax.set_title("Throughput over Simplex of 3 parameters")
tax.ticks(axis='lbr', linewidth=1, multiple=5)
tax.clear_matplotlib_ticks()
tax.show()

# %%
scale = 10

figure, tax = ternary.figure(scale=10)
figure.set_size_inches(10, 8)
tax.heatmap(runtime_dict, style="triangular")
tax.boundary(linewidth=2.0)
tax.set_title("Runtime over Simplex of 3 parameters")
tax.ticks(axis='lbr', linewidth=1, multiple=5)
tax.clear_matplotlib_ticks()
tax.show()
