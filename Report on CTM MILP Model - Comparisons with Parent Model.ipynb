# %% [markdown]
# # Report on CTM MILP Model - Comparisons with Parent Model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random
from pprint import pprint
import time

from ctmmodels.const import *
from ctmmodels.ringbarrier import DTSimplexRingBarrier as NewModel
from ctmmodels.parentmodel import ParentModel as OldModel

# %%
IMAGE_PATH = 'graphs/'
DF_PATH = 'dataframes/'

# %% [markdown]
# **Notes on the models and parameters being used:**
#
# * 2 separate formulations were made: 1 dealing with individual movements in the intersection, and another dealing with phases in the stoplight. The latter has 33% less binary variables, and thus performed better in basic tests.
#
# * Saturation flow rate will be set to 600 vph instead of the 450 vph in the parent paper; this is so as to test both under and over saturated conditions.
#
# * Traffic will be distributed evenly between the 3 possible turns (left, through, and right). This is based on previous tests where left was getting essentially 0 green time.
#
# * Time range will be set to 60 seconds, or 30 time steps at 2 seconds per time step. Preliminary experiments show that 50 is the optimal cycle time for both delay and throughput (at demands ranging from 450 to 900 vph). *However*, previous tests on this model showed that no time was allotted to left turns when the cycle time was too small.

# %%
time_range = 30 # time steps
time_ticks = np.arange(0, time_range+1, 1)

parameters = {
    'r_left': 1.0/3.0,
    'r_through': 1.0/3.0,
    'r_right': 1.0/3.0,
    'sat_flow_rate': 1800,
    'time_range': time_range,
    'time_step': 2,
    'g_min': 6,
    'g_max': 20
}

# Varying parameters: demand, use_flow_weight, flow_weight, alpha

# %%
def run_model(demand, log_output=False, newmodel=False):
    # Hardcode simplex parameters for new model
    if newmodel:
        model = NewModel(
            demand=demand,
            alpha=0.4,
            beta=0.4,
            gamma=0.2,
            **parameters
        )
    else:
        model = OldModel(
            demand=demand,
            **parameters
        )
    model.generate()
    runtime = model.solve(log_output=log_output)
    dfx, dfy, dfg = model.return_solution()
    dfparams = model.return_parameters()
    obj_values = model.return_objective_value()
    return dfx, dfy, dfg, dfparams, obj_values, runtime

# %% [markdown]
# ## Intersection Cell Network

# %% [markdown]
# ![title](img/4leg-intersection.png)

# %% [markdown]
# ## Setting the path of cells to check

# %%
_approach = 0

_approach_terms = [
    'Left',
    'Through',
    'Right'
]

_cell_path = [
    (CELL_SOURCE,0,_approach),
    (CELL_NORMAL,0,_approach),
    (CELL_NORMAL,1,_approach),
    (CELL_NORMAL,2,_approach),
    (CELL_MOVEMENT,THROUGH_TURN,_approach),
    S_mapping((CELL_MOVEMENT,THROUGH_TURN,_approach))[0]
]

def movement_paths(approach):
    return [
        [
            (CELL_SOURCE,0,approach),
            (CELL_NORMAL,0,approach),
            (CELL_NORMAL,1,approach),
            (CELL_NORMAL,2,approach),
            (CELL_MOVEMENT,LEFT_TURN,approach),
            S_mapping((CELL_MOVEMENT,LEFT_TURN,approach))[0]
        ],
        [
            (CELL_SOURCE,0,approach),
            (CELL_NORMAL,0,approach),
            (CELL_NORMAL,1,approach),
            (CELL_NORMAL,2,approach),
            (CELL_MOVEMENT,THROUGH_TURN,approach),
            S_mapping((CELL_MOVEMENT,THROUGH_TURN,approach))[0]
        ],
        [
            (CELL_SOURCE,0,approach),
            (CELL_NORMAL,0,approach),
            (CELL_NORMAL,1,approach),
            (CELL_NORMAL,2,approach),
            (CELL_MOVEMENT,RIGHT_TURN,approach),
            S_mapping((CELL_MOVEMENT,RIGHT_TURN,approach))[0]
        ]
    ]

# %% [markdown]
# ## Comparing cell volumes

# %%
def plot_volume(dfx, cell_path, title, headless=True, filename='volume.png'):
    dfx_approach = pd.concat([
        dfx[dfx.cell == c].sort_values(by='timestep')
        for c in cell_path
    ]).pivot(index='timestep', columns='cell', values='volume')
    
    fig, axs = plt.subplots(1,2, figsize=(20,10))
    
    sns.lineplot(data=dfx_approach, ax=axs[0])
    sns.lineplot(data=dfx_approach.cumsum(), ax=axs[1])

    axs[0].set_title('Volume of cells')
    axs[0].set_xlabel('Timesteps')
    axs[0].set_ylabel('Instantaneous volume')
    axs[0].set_xticks(time_ticks, minor=True)

    axs[1].set_title('Volume of cells (cumulative)')
    axs[1].set_xlabel('Timesteps')
    axs[1].set_ylabel('Cumulative volume')
    axs[1].set_xticks(time_ticks, minor=True)
    
    fig.suptitle(title, fontsize=18)
    
    if headless:
        fig.savefig(IMAGE_PATH + filename)
        plt.close(fig)

# %% [markdown]
# ## Comparing flows

# %%
def plot_flow(dfy, cell_path, title, headless=True, filename='flow.png'):
    dfy_approach = pd.concat([
        dfy[dfy.cell_from == c].groupby(['cell_from', 'timestep']).agg({'flow': 'sum'}).sort_values(by='timestep')
        for c in cell_path
    ]).reset_index().pivot(index='timestep', columns='cell_from', values='flow')
    
    fig, axs = plt.subplots(1,2, figsize=(20,10))

    sns.lineplot(data=dfy_approach, ax=axs[0])
    sns.lineplot(data=dfy_approach.cumsum(), ax=axs[1])

    axs[0].set_title('Flow from cells')
    axs[0].set_xlabel('Timesteps')
    axs[0].set_ylabel('Instantaneous flow')
    axs[0].set_xticks(time_ticks, minor=True)

    axs[1].set_title('Flow from cells (cumulative)')
    axs[1].set_xlabel('Timesteps')
    axs[1].set_ylabel('Cumulative flow')
    axs[1].set_xticks(time_ticks, minor=True)
    
    fig.suptitle(title, fontsize=18)
    
    if headless:
        fig.savefig(IMAGE_PATH + filename)
        plt.close(fig)

# %% [markdown]
# ## Comparing specific green time

# %%
# Heatmap form
def plot_greentimemap(dfg, title, headless=True, filename='greentime.png', newmodel=False):
    fig, axs = plt.subplots(figsize=(18,8))

    dfg_matrix = dfg.pivot(index='cell', columns='timestep', values='is_green')
    if newmodel:
#         dfg_matrix = dfg_matrix.reindex(index=[
            
#         ])
        pass
    else:
        dfg_matrix = dfg_matrix.reindex(index=[
            (2,LEFT_TURN,EASTBOUND), (2,RIGHT_TURN,EASTBOUND), (2,THROUGH_TURN,EASTBOUND),
            (2,LEFT_TURN,NORTHBOUND), (2,RIGHT_TURN,NORTHBOUND), (2,THROUGH_TURN,NORTHBOUND),
            (2,LEFT_TURN,SOUTHBOUND), (2,RIGHT_TURN,SOUTHBOUND), (2,THROUGH_TURN,SOUTHBOUND),
            (2,LEFT_TURN,WESTBOUND), (2,RIGHT_TURN,WESTBOUND), (2,THROUGH_TURN,WESTBOUND),
        ])
    sns.heatmap(data=dfg_matrix)
    
    fig.suptitle(title, fontsize=18)
    
    if headless:
        fig.savefig(IMAGE_PATH + filename)
        plt.close(fig)

# %% [markdown]
# ## Generating graphs for each model case

# %%
def generate_graphs(dfx, dfy, dfg, capacity, max_flow, demand, alpha, flow_weight, folder=''):
    cell_paths = movement_paths(_approach)
    
    for ndx, cellpath in enumerate(cell_paths):
        if dfx is not None:
            plot_volume(dfx,
                        cellpath,
                        '''Volume in cells at {} vph and {}% delay weight ({} turn)
                        (Cap: {:.2f}, Max Flow: {}, Flow Weight: {})'''
                            .format(demand, alpha*100, _approach_terms[ndx], capacity, max_flow, flow_weight),
                        filename=folder+'volumes/{}vph_{}alpha_{}flow_volume_{}.png'
                            .format(demand, alpha, flow_weight, _approach_terms[ndx].lower()))
        
        if dfy is not None:
            plot_flow(dfy,
                      cellpath,
                      '''Flow from cells at {} vph and {}% delay weight ({} turn)
                      (Cap: {:.2f}, Max Flow: {}, Flow Weight: {})'''
                          .format(demand, alpha*100, _approach_terms[ndx], capacity, max_flow, flow_weight),
                      filename=folder+'flows/{}vph_{}alpha_{}flow_flow_{}.png'
                          .format(demand, alpha, flow_weight, _approach_terms[ndx].lower()))
    
    if dfg is not None:
        plot_greentimemap(dfg,
                       '''Green times at {} vph and {}% delay weight
                       (Cap: {:.2f}, Max Flow: {}, Flow Weight: {})'''
                           .format(demand, alpha*100, capacity, max_flow, flow_weight),
                       filename=folder+'greentimes/{}vph_{}alpha_{}flow_greetime.png'
                           .format(demand, alpha, flow_weight))

# %%
def plot_obj_values(obj_values, title, xaxis, xlabel, headless=True, filename='obj.png'):
    fig, axs = plt.subplots(1,2,figsize=(20,10))

    axs[0].plot(xaxis, [x[0] for x in obj_values])
    axs[0].set_title("Computed total delay")
    axs[0].set_ylabel("Total vehicle delay (timesteps)")
    axs[0].set_xlabel(xlabel)

    axs[1].plot(xaxis, [x[1] for x in obj_values])
    axs[1].set_title("Computed total throughput")
    axs[1].set_ylabel("Total vehicle throughput (veh)")
    axs[1].set_xlabel(xlabel)
    
    fig.suptitle(title, fontsize=18)
    
    if headless:
        fig.savefig(IMAGE_PATH + filename)
        plt.close(fig)

# %% [markdown]
# ## Saving dataframes

# %%
def save_df(df, filename):
    df.to_pickle(DF_PATH + filename + ".pkl")

# %% [markdown]
# ## 1. Generating Greentimes from NewModel, FixedNewModel, and OldModel

# %% [markdown]
# ### New Model

# %%
dfx, dfy, dfg, dfparams, obj_values, runtime = run_model(demand=(450,900), log_output=True, newmodel=True)
# Out:
# Solving...
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 2 times.
# MIP Presolve eliminated 3202 rows and 292 columns.
# MIP Presolve modified 692 coefficients.
# Aggregator did 160 substitutions.
# Reduced MIP has 3440 rows, 1888 columns, and 11804 nonzeros.
# Reduced MIP has 270 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.04 sec. (13.51 ticks)
# Found incumbent of value 1026.332332 after 0.05 sec. (24.54 ticks)
# Probing fixed 0 vars, tightened 128 bounds.
# Probing time = 0.02 sec. (0.61 ticks)
# Tried aggregator 2 times.
# MIP Presolve eliminated 604 rows and 104 columns.
# Aggregator did 88 substitutions.
# Reduced MIP has 2748 rows, 1696 columns, and 10096 nonzeros.
# Reduced MIP has 270 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (5.34 ticks)
# Probing time = 0.03 sec. (0.42 ticks)
# Tried aggregator 1 time.
# Reduced MIP has 2748 rows, 1696 columns, and 10096 nonzeros.
# Reduced MIP has 270 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (6.74 ticks)
# Probing time = 0.03 sec. (0.52 ticks)
# Clique table members: 540.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 4 threads.
# Root relaxation solution time = 0.14 sec. (131.86 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                         1026.3323    -2505.3173           344.10%
#       0     0      -28.4105   159     1026.3323      -28.4105        0  102.77%
# *     0+    0                          111.3778      -28.4105           125.51%
#       0     0      -24.3730   154      111.3778     Cuts: 115      153  121.88%
# *     0+    0                           88.9282      -24.3730           127.41%
# *     0+    0                           43.4557      -24.3730           156.09%
#       0     0      -17.8887   177       43.4557      Cuts: 83      496  141.17%
#       0     0      -16.3189   153       43.4557     Cuts: 160      659  137.55%
#       0     0      -15.9934   155       43.4557      Cuts: 96      722  136.80%
#       0     0      -15.9572   165       43.4557      Cuts: 47      776  136.72%
# *     0+    0                           43.3138      -15.9572           136.84%
#       0     0      -15.9314   156       43.3138      Cuts: 40      823  136.78%
#       0     0      -15.9314   165       43.3138    MIRcuts: 4      825  136.78%
# *     0+    0                           24.0232      -15.9314           166.32%
#       0     2      -15.9314   153       24.0232      -14.9065      825  162.05%
# Elapsed time = 1.96 sec. (976.50 ticks, tree = 0.01 MB, solutions = 6)
#      64    40        1.9009   130       24.0232      -13.6793     5917  156.94%
#     166   113       23.8799    46       24.0232      -11.8809    13467  149.46%
# *   222   150      integral     0       23.3986      -10.9981    16138  147.00%
#     280   174       17.4197    87       23.3986       -8.2724    20886  135.35%
#     465   287       21.7176    92       23.3986       -5.5551    31610  123.74%
# *   536+  318                           21.5134       -5.5551           125.82%
#     634   380        cutoff             21.5134       -3.4074    41042  115.84%
#     824   441       21.0030    49       21.5134       -0.6762    48771  103.14%
# *   882+  450                           20.5169       -0.5671           102.76%
# *   882+  449                           19.3015       -0.5671           102.94%
# *   882+  449                           19.2146       -0.5671           102.95%
#     882   451        0.5297   122       19.2146       -0.5671    50471  102.95%
# *   896+  489                           19.2146       -0.3183           101.66%
#    1013   456       13.5421   117       19.2146       -0.0832    60614  100.43%
#    1222   554       12.9860    69       19.2146        2.0790    72510   89.18%
# *  1576+  735                           19.0039        4.1292            78.27%
#    2053   925       16.7918    96       19.0039        6.5798   115726   65.38%
# Elapsed time = 7.48 sec. (4254.55 ticks, tree = 1.41 MB, solutions = 13)
# *  2057+  889                           18.1785        6.5798            63.80%
# *  2059+  900                           18.1785        6.5798            63.80%
#    2804  1052       11.7284    71       18.1785        9.1576   150085   49.62%
#    3747  1264       17.0720    97       18.1785       11.0227   190281   39.36%
#    3789  1332      -11.6059   176       18.1785       11.2893   205554   37.90%
#    3917    45        5.8684   140       18.1785       11.2893   213319   37.90%
#    4350   329       -0.1310   127       18.1785       11.2893   245459   37.90%
#    4869   603       18.0432    50       18.1785       11.2893   281490   37.90%
#    5489   868        6.1834    85       18.1785       11.2893   312825   37.90%
#    6133  1177       15.4901    74       18.1785       11.2893   354367   37.90%
# *  6727  1407      integral     0       17.6742       11.2893   384558   36.13%
#    6791  1438       17.8754    65       17.6742       11.2893   390764   36.13%
# *  7270+ 1579                           17.5796       11.2893            35.78%
# *  7280  1581      integral     0       17.2958       11.2893   426575   34.73%
#    7397  1586       13.2416   116       17.2958       11.2893   427079   34.73%
# Elapsed time = 23.22 sec. (14803.77 ticks, tree = 2.17 MB, solutions = 17)
# *  7525+ 1561                           16.6528       11.2893            32.21%
#    8131  1563       15.9184    64       16.6528       11.2893   473685   32.21%
#    8494  1617      -10.9061   174       16.6528       11.2893   503422   32.21%
#    8821   184       12.6181   106       16.6528       11.2893   530838   32.21%
#    9304   420       16.1092   104       16.6528       11.2893   554721   32.21%
#    9949   679        8.5674    95       16.6528       11.2893   585629   32.21%
#   10580   838        cutoff             16.6528       11.2893   611197   32.21%
#   11209   938       14.1929    68       16.6528       11.2893   638726   32.21%
# * 11259   952      integral     0       16.2993       11.2893   637905   30.74%
#   11891   935        cutoff             16.2993       11.5140   666543   29.36%
#   12620   895        cutoff             16.2993       12.8139   691173   21.38%
#   13414   727       15.9112    91       16.2993       14.1065   721002   13.45%
# Elapsed time = 40.43 sec. (26146.18 ticks, tree = 5.74 MB, solutions = 19)
# * 14212   273      integral     0       15.9458       15.4926   743084    2.84%
#
# GUB cover cuts applied:  7
# Clique cuts applied:  39
# Cover cuts applied:  42
# Flow cuts applied:  20
# Mixed integer rounding cuts applied:  25
# Zero-half cuts applied:  4
# Lift and project cuts applied:  14
# Gomory fractional cuts applied:  35
#
# Root node processing (before b&c):
#   Real time             =    1.96 sec. (974.20 ticks)
# Parallel b&c, 4 threads:
#   Real time             =   40.04 sec. (26010.32 ticks)
#   Sync time (average)   =    2.55 sec.
#   Wait time (average)   =    0.10 sec.
#                           ------------
# Total (root+branch&cut) =   42.01 sec. (26984.52 ticks)
# Done!
# Time elapsed: 42.152009964

# %%
#print(c_obj_values)
print(obj_values)
# Out:
# (1537.7932281090914, 44.55696202531644, 15.94576343126582)

# %%
plot_volume(dfx, _cell_path, "New Model (600 vphpl)", headless=False, filename='flow.png')

# %%
plot_greentimemap(dfg, "New Model (600 vphpl)", headless=False, newmodel=True)

# %% [markdown]
# ### Old Model

# %%
dfx, dfy, dfg, dfparams, obj_values, runtime = run_model(demand=(450, 900), log_output=True, newmodel=False)
# Out:
# Solving...
# CPXPARAM_Read_DataCheck                          1
# Tried aggregator 2 times.
# MIP Presolve eliminated 2818 rows and 380 columns.
# MIP Presolve modified 524 coefficients.
# Aggregator did 556 substitutions.
# Reduced MIP has 3496 rows, 1884 columns, and 11720 nonzeros.
# Reduced MIP has 270 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.02 sec. (12.97 ticks)
# Found incumbent of value 0.000000 after 0.04 sec. (23.74 ticks)
# Probing time = 0.02 sec. (0.63 ticks)
# Tried aggregator 1 time.
# Reduced MIP has 3496 rows, 1884 columns, and 11720 nonzeros.
# Reduced MIP has 270 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.01 sec. (7.14 ticks)
# Probing time = 0.03 sec. (0.86 ticks)
# Clique table members: 1020.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 4 threads.
# Root relaxation solution time = 0.19 sec. (161.55 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                            0.0
#   15492  4507       94.6635    58       94.0696       96.5384  1220161    2.62%
# Elapsed time = 113.24 sec. (66207.64 ticks, tree = 85.14 MB, solutions = 8)
#   15782  4513        cutoff             94.0696       96.4951  1254044    2.58%
#   16116  4508        cutoff             94.0696       96.4251  1278966    2.50%
#   16429  4512       94.1081   107       94.0696       96.3888  1288323    2.47%
#   16771  4505       94.2546    82       94.0696       96.3361  1303633    2.41%
#   17100  4512       94.5417    46       94.0696       96.3007  1321368    2.37%
#   17440  4472       94.0928    84       94.0696       96.2281  1348377    2.29%
#   17782  4411       94.9513    87       94.0696       96.1690  1382460    2.23%
#   18095  4381        cutoff             94.0696       96.1131  1391961    2.17%
#   18389  4327       95.0287   104       94.0696       96.0385  1412039    2.09%
#   18739  4266        cutoff             94.0696       95.9643  1431678    2.01%
# Elapsed time = 128.95 sec. (75764.19 ticks, tree = 73.71 MB, solutions = 8)
#   19086  4180        cutoff             94.0696       95.9255  1454465    1.97%
#   19442  4120       94.3333    71       94.0696       95.8184  1476017    1.86%
#   19780  3951        cutoff             94.0696       95.7383  1505463    1.77%
#   20147  3854       95.1682   111       94.0696       95.6732  1524070    1.70%
#   20552  3707        cutoff             94.0696       95.5855  1551045    1.61%
#   20944  3582       94.1067    74       94.0696       95.4948  1568845    1.51%
#   21280  3428        cutoff             94.0696       95.4042  1588233    1.42%
#   21716  3179       94.5054    73       94.0696       95.2856  1614925    1.29%
#   22204  2874        cutoff             94.0696       95.1727  1640667    1.17%
#   22711  2646        cutoff             94.0696       95.0620  1660044    1.05%
# Elapsed time = 144.73 sec. (85320.32 ticks, tree = 36.90 MB, solutions = 8)
#   23257  2149       94.1468    59       94.0696       94.8961  1691602    0.88%
#   23888  1612        cutoff             94.0696       94.7070  1716872    0.68%
#   24676   906        cutoff             94.0696       94.4585  1738741    0.41%
#   25551    45        cutoff             94.0696       94.2488  1751988    0.19%
#   25565   359        cutoff             94.0696       94.2488  1748779    0.19%
#   25566   368        cutoff             94.0696       94.2488  1748665    0.19%
#
# GUB cover cuts applied:  30
# Clique cuts applied:  93
# Cover cuts applied:  113
# Implied bound cuts applied:  58
# Flow cuts applied:  47
# Mixed integer rounding cuts applied:  30
# Zero-half cuts applied:  11
# Lift and project cuts applied:  2
# Gomory fractional cuts applied:  24
#
# Root node processing (before b&c):
#   Real time             =    4.35 sec. (2310.10 ticks)
# Parallel b&c, 4 threads:
#   Real time             =  173.23 sec. (112302.31 ticks)
#   Sync time (average)   =   21.42 sec.
#   Wait time (average)   =    0.11 sec.
#                           ------------
# Total (root+branch&cut) =  177.58 sec. (114612.41 ticks)
# Done!
# Time elapsed: 177.633587122

# %%
#print(c_obj_values)
print(obj_values)
# Out:
# 99.0281293952

# %%
plot_volume(dfx, _cell_path, "New Model (600 vphpl)", headless=False, filename='flow.png')

# %%
plot_greentimemap(dfg, "Old Model (600 vphpl)", headless=False)
